# %% [markdown]
# # Reduce image data products
#
# Now that we have some/the images (CTX, Hirise, HRSC) downloaded we should process (reduce, transform, etc) them to a final, science-ready state.
#
# CTX/EDR images are the most costly ones since they are in "raw" format, we need to go all the way through signal calibration, intrument-to-planet projection and other instrument correstions, up to the generation of the final GeoTIFF file.
#
# Hirise/RDR and HRSC/REFDR products are simpler, those are already _reduce_ data; Map (re)projection and file formatting are basically all to be done.

# %%
downloaded_products = 'Mawrth_Vallis_downloaded_sample_products.geojson'

# %%
import npt

# %%
import geopandas
import pandas
pandas.set_option('display.max_columns',100)

# %%
gdf = geopandas.read_file(downloaded_products)

gdf
# Out:
#   Center_latitude Center_longitude Easternmost_longitude Emission_angle  \
# 0         29.7761         341.8979                342.89           None
# 1         16.2676         344.0262               345.891           None
# 2         23.2688         342.4958                 342.8           5.85
# 3         24.3758         342.2817                342.87           0.09
# 4         23.2452         342.5015               342.563       5.816564
# 5         22.2517          342.551               342.621       0.295027
#
#   Footprints_cross_meridian Incidence_angle Map_scale Maximum_latitude  \
# 0                     False            None      12.5           40.065
# 1                     False            None        25          23.9027
# 2                     False           48.88      5.66          23.6504
# 3                     False           59.39      5.66          27.0054
# 4                     False       48.900419      0.25          23.3293
# 5                     False       58.737351      0.25          22.4007
#
#   Minimum_latitude            Observation_time Phase_angle  \
# 0           19.519  2005-01-19T19:06:48.344002        None
# 1            8.632  2005-09-29T15:28:07.719000        None
# 2          22.8866  2006-11-12T15:12:52.777000       43.11
# 3          21.7462  2007-02-18T05:52:00.318000       59.41
# 4           23.161  2006-11-12T15:12:52.248001   43.137054
# 5          22.1027  2007-02-18T05:51:20.181000   58.835998
#
#   Product_creation_time Solar_longitude Target_name  \
# 0   2016-03-04T20:31:26            None        MARS
# 1   2016-03-14T11:38:04            None        MARS
# 2   2007-05-18T22:07:23          134.36        MARS
# 3   2007-08-09T21:43:46          185.96        MARS
# 4   2009-09-22T22:45:09       134.35984        MARS
# 5   2009-11-11T10:51:58      185.953173        MARS
#
#                UTC_start_time               UTC_stop_time  \
# 0  2005-01-19T19:04:06.841000  2005-01-19T19:09:29.847000
# 1  2005-09-29T15:25:45.728001  2005-09-29T15:30:29.709999
# 2  2006-11-12T15:12:46.050999  2006-11-12T15:12:59.504002
# 3  2007-02-18T05:51:11.313000  2007-02-18T05:52:49.324001
# 4  2006-11-12T15:12:50.716999  2006-11-12T15:12:53.779999
# 5  2007-02-18T05:51:17.450001  2007-02-18T05:51:22.912001
#
#   Westernmost_longitude                                         browse_url  \
# 0               340.677  https://pds-geosciences.wustl.edu/mex/mex-m-hr...
# 1               342.568  https://pds-geosciences.wustl.edu/mex/mex-m-hr...
# 2                342.19                                               None
# 3                341.66                                               None
# 4               342.439  https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/...
# 5               342.481  https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/...
#
#                            id    inst mission    type  \
# 0          H1293_0000_ND3.JP2    HRSC     MEX  REFDR3
# 1          H2196_0001_ND3.JP2    HRSC     MEX  REFDR3
# 2  P01_001388_2034_XI_23N017W     CTX     MRO     EDR
# 3  P04_002641_2046_XN_24N017W     CTX     MRO     EDR
# 4         PSP_001388_2035_RED  HIRISE     MRO  RDRV11
# 5         PSP_002641_2025_RED  HIRISE     MRO  RDRV11
#
#                                 image_path  \
# 0             data/hrsc/h1293_0000_nd3.jp2
# 1             data/hrsc/h2196_0001_nd3.jp2
# 2  data/ctx/P01_001388_2034_XI_23N017W.IMG
# 3  data/ctx/P04_002641_2046_XN_24N017W.IMG
# 4      data/hirise/PSP_001388_2035_RED.JP2
# 5      data/hirise/PSP_002641_2025_RED.JP2
#
#                                 label_path  \
# 0             data/hrsc/h1293_0000_nd3.lbl
# 1             data/hrsc/h2196_0001_nd3.lbl
# 2  data/ctx/P01_001388_2034_XI_23N017W.lbl
# 3  data/ctx/P04_002641_2046_XN_24N017W.lbl
# 4      data/hirise/PSP_001388_2035_RED.LBL
# 5      data/hirise/PSP_002641_2025_RED.LBL
#
#                                             geometry
# 0  POLYGON ((-17.82000 40.06500, -17.81000 39.882...
# 1  POLYGON ((-16.59400 8.63200, -16.60100 8.78700...
# 2  POLYGON ((-17.29000 23.65040, -17.20000 22.936...
# 3  POLYGON ((-17.80000 27.00540, -17.13000 21.805...
# 4  POLYGON ((-17.43700 23.17200, -17.54100 23.161...
# 5  POLYGON ((-17.37900 22.11410, -17.48200 22.102...

# %%
import json

gjson_ctx = json.loads(gdf.query('inst == "CTX"').to_json())

gjson_hirise = json.loads(gdf.query('inst == "HIRISE"').to_json())

gjson_hrsc = json.loads(gdf.query('inst == "HRSC"').to_json())

# %%
from npt import isis
isis.set_docker('isis3')

# %% [markdown]
# ## CTX
#
# Someone said: "do the hard tasks first" -- seems reasonable. So let's do CTX/EDR processing first.

# %%
gjson_ctx_reduced = npt.reduce.from_geojson(gjson_ctx, dataset='mars/mro/ctx/edr')
# Out:
# INFO:__init__._run_file(): Temp dir: '/var/folders/b1/frq3gywj3ljfqrf1yc7zk06r0000gn/T/neanias_19jgr3wt'
# INFO:__init__.reduce_ctx(): File 'data/ctx/P01_001388_2034_XI_23N017W.IMG' copied
# INFO:sh.info(): <Command "/usr/local/bin/docker exec -t isis3 bash --login -c 'mroctx2isis FROM=/var/folders/b1/frq3gywj3ljfqrf1yc7zk06r0000gn/T/neanias_19jgr3wt/P01_001388_2034_XI_23N017W.IMG TO=/var/folders/b1/frq3gywj3ljfqrf1yc7zk06r0000gn/T/neanias_19jgr3wt/P01_001388_2034_XI_23N017W.cub'", pid 91724>: process started
# ERROR:__init__.reduce_ctx():
#
#   RAN: /usr/local/bin/docker exec -t isis3 bash --login -c 'mroctx2isis FROM=/var/folders/b1/frq3gywj3ljfqrf1yc7zk06r0000gn/T/neanias_19jgr3wt/P01_001388_2034_XI_23N017W.IMG TO=/var/folders/b1/frq3gywj3ljfqrf1yc7zk06r0000gn/T/neanias_19jgr3wt/P01_001388_2034_XI_23N017W.cub'
#
#   STDOUT:
# **ERROR** File could not be opened.
# **I/O ERROR** Unable to open [/var/folders/b1/frq3gywj3ljfqrf1yc7zk06r0000gn/T/neanias_19jgr3wt/P01_001388_2034_XI_23N017W.IMG].
#
#
#   STDERR:
# ---------------------------------------------------------------------------
# ErrorReturnCode_1                         Traceback (most recent call last)
# Input In [8], in <module>
# ----> 1 gjson_ctx_reduced = npt.reduce.from_geojson(gjson_ctx, dataset='mars/mro/ctx/edr')
#
# File ~/Coisas/repos/NEANIAS/npt/npt/reduce/__init__.py:28, in from_geojson(geojson, dataset, basepath)
#      26 new_features = []
#      27 for feature in features:
# ---> 28     new_feature = from_feature(feature, dataset, basepath)
#      29     assert id(new_feature) != id(feature)
#      30     new_features.append(new_feature)
#
# File ~/Coisas/repos/NEANIAS/npt/npt/reduce/__init__.py:47, in from_feature(geojson_feature, dataset, basepath, projection, tmpdir, keep_tmpdir, overwrite)
#      45 feature = geojson_feature.copy()
#      46 properties = feature['properties']
# ---> 47 properties = _run_props(properties, dataset=dataset, basepath=basepath,
#      48                         projection=projection,
#      49                         tmpdir=tmpdir, keep_tmpdir=keep_tmpdir,
#      50                         overwrite=overwrite)
#      51 feature['properties'] = properties
#      52 echo("Post-processed feature: {!s}".format(feature))
#
# File ~/Coisas/repos/NEANIAS/npt/npt/reduce/__init__.py:64, in _run_props(properties, dataset, basepath, projection, tmpdir, keep_tmpdir, overwrite)
#      62 properties = properties.copy()
#      63 image_filename = properties['image_path']
# ---> 64 tif = _run_file(image_filename,
#      65     basepath=basepath,
#      66     projection=projection,
#      67     tmpdir=tmpdir,
#      68     dataset=dataset,
#      69     overwrite=overwrite,
#      70     keep_tmpdir=keep_tmpdir)
#      71 echo("Output file (TIF): {!s}".format(tif))
#      72 if tif:
#      73     # echo("IF 'out' (non-null output)")
#      74     # assert len(out) == 2, "Was expecting a tuple of filenames (CUB,TIF). Instead got {!s}".format(out)
#    (...)
#      77     # echo("GeoTIFF output file: {!s}".format(img_tiff))
#      78     #TODO: change 'image_path' to 'cube_path'. 'image_path' to stay pointing to source file
#
# File ~/Coisas/repos/NEANIAS/npt/npt/reduce/__init__.py:136, in _run_file(filename, dataset, basepath, projection, tmpdir, keep_tmpdir, overwrite, cog, make_dirs)
#     133     log.info("Temp dir: '{}'".format(tmpdir))
#     135 if 'ctx' in dataset:
# --> 136     f_tif = reduce_ctx(filename, projection, tmpdir)
#     137 elif 'hirise' in dataset:
#     138     f_tif = reduce_hirise(filename, tmpdir)
#
# File ~/Coisas/repos/NEANIAS/npt/npt/reduce/__init__.py:210, in reduce_ctx(filename_init, map_projection, tmpdir)
#     208 except Exception as err:
#     209     log.error(err)
# --> 210     raise err
#     211 else:
#     212     log.info("Processing finished, file '{}' created.".format(f_tif))
#
# File ~/Coisas/repos/NEANIAS/npt/npt/reduce/__init__.py:178, in reduce_ctx(filename_init, map_projection, tmpdir)
#     174 # FORMAT (pds->isis)
#     175 # -- Transfrom PDS (IMG) into ISIS (CUB) file
#     176 f_cub = _change_file_extension(f_in, 'cub')
# --> 178 format.pds2isis(f_in, f_cub)
#     179 # -- Init SPICE kernel
#     180 # format.init_spice(f_cub)
#     181
#    (...)
#     186
#     187 # CALIBRATION
#     188 from npt.isis import calibration
#
# File ~/Coisas/repos/NEANIAS/npt/npt/isis/format.py:18, in pds2isis(filename_in, filename_out, dataset)
#      16 assert dataset in _dstools['pds2isis'], "Dataset '{}' not supported.".format(dataset)
#      17 foo = _dstools['pds2isis'][dataset]
# ---> 18 res = foo(FROM=filename_in, TO=filename_out)
#      19 sh.log(res)
#      20 return res
#
# File ~/Coisas/repos/NEANIAS/npt/npt/isis/_sh.py:62, in _wrapper.<locals>._sh(*args, **kwargs)
#      60 comm = ' '.join(exec+v+kv)
#      61 log.debug(comm)
# ---> 62 return sh(comm)
#
# File ~/Coisas/repos/NEANIAS/npt/npt/isis/_sh.py:31, in Sh.__call__(self, *args, **kwargs)
#      30 def __call__(self, *args, **kwargs):
# ---> 31     return self._sh(*args, **kwargs)
#
# File /opt/miniconda3/envs/npt/lib/python3.10/site-packages/sh.py:1566, in Command.__call__(self, *args, **kwargs)
#    1563 if output_redirect_is_filename(stderr):
#    1564     stderr = open(str(stderr), "wb")
# -> 1566 return RunningCommand(cmd, call_args, stdin, stdout, stderr)
#
# File /opt/miniconda3/envs/npt/lib/python3.10/site-packages/sh.py:822, in RunningCommand.__init__(self, cmd, call_args, stdin, stdout, stderr)
#     819 self.log.info("process started")
#     821 if should_wait:
# --> 822     self.wait()
#
# File /opt/miniconda3/envs/npt/lib/python3.10/site-packages/sh.py:879, in RunningCommand.wait(self, timeout)
#     876     raise TimeoutException(-exit_code, self.ran)
#     878 else:
# --> 879     self.handle_command_exit_code(exit_code)
#     881     # if an iterable command is using an instance of OProc for its stdin,
#     882     # wait on it.  the process is probably set to "piped", which means it
#     883     # won't be waited on, which means exceptions won't propagate up to the
#     884     # main thread.  this allows them to bubble up
#     885     if self.process._stdin_process:
#
# File /opt/miniconda3/envs/npt/lib/python3.10/site-packages/sh.py:905, in RunningCommand.handle_command_exit_code(self, code)
#     901 if exc_class:
#     902     exc = exc_class(
#     903         self.ran, self.process.stdout, self.process.stderr, ca["truncate_exc"]
#     904     )
# --> 905     raise exc
#
# ErrorReturnCode_1:
#
#   RAN: /usr/local/bin/docker exec -t isis3 bash --login -c 'mroctx2isis FROM=/var/folders/b1/frq3gywj3ljfqrf1yc7zk06r0000gn/T/neanias_19jgr3wt/P01_001388_2034_XI_23N017W.IMG TO=/var/folders/b1/frq3gywj3ljfqrf1yc7zk06r0000gn/T/neanias_19jgr3wt/P01_001388_2034_XI_23N017W.cub'
#
#   STDOUT:
# **ERROR** File could not be opened.
# **I/O ERROR** Unable to open [/var/folders/b1/frq3gywj3ljfqrf1yc7zk06r0000gn/T/neanias_19jgr3wt/P01_001388_2034_XI_23N017W.IMG].
#
#
#   STDERR:
