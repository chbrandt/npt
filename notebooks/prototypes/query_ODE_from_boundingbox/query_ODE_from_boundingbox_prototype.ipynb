# %% [markdown]
# # Query ODE for products intersecting bounding-box
#
# [ODE's REST manual]: http://oderest.rsl.wustl.edu/ODE_REST_V2.1.pdf
#
# From [ODE's REST manual], sections 3, 3.1, we learn we can query ODE
# for products intersecting a bounding-box through the following attributes:
#
# * `loc`: limit search by location
#   * `f`: Input bounding box / footprint intersects a product’s footprint (Default)
#
# * `minlat`: I'd say to limit latitudes to [-65:65] to skip poles for the time being
# * `maxlat`: I'd say to limit latitudes to [-65:65] to skip poles for the time being
# * `westlon`: [0:360], positive east
# * `eastlon`: [0:360], positive east
#
# And from [ODE's REST manual], page 20:
# > Notes:
# > 1) A requested bounding box is not valid unless all parameters (the minlat, maxlat, westernlon, and easterlon) are given. If any one of the parameters is missing, the requested bounding box is ignored.
# > 2) If a requested bounding box or a requested footprint is given and no “loc” parameter is given, the default to “loc=f”
# > 3) All latitudes are planetocentric
# > 4) All longitude are positive east 0-360
# > 5) Bounding boxes may cross the meridian
# > 6) A bounding box may be a point or line but will not return results if loc=o
# > See section 3.3.1 for examples of both bounding box and footprint queries with different loc= parameters.
#
# * `proj`
#   * `c0`: Cylindrical Center Lon 0 (-180 to 180)
#   * `c180`: Cylindrical Center Lon 180 ( 0 to 360)
#
# > About coordinate systems in ODE: https://ode.rsl.wustl.edu/mars/pagehelp/quickstartguide/index.html
#
# * `ihid`: Instrument host ID
#   * mro
#   * mex
#   * mgs
#
# * `pt`: Product type
#   * RDRV11
#
# * `iid`
#   * `hirise`
#
# * `query`: Return list of products with selected product metadata that meet the query parameters
#   * `product`
#
# * `results`
#   * `f`: Product files
#   * `p`: PDS Product Identifies
#   * `m`: Product metadata
#   * `c`: Count products
#
# * `output`: query output format, XML or JSON (default XML)
#   * `JSON`
#
# Examples:
#
# * Query for (count of) HiRISE products intersecting a bounding-box:
#   ```
#   http://oderest.rsl.wustl.edu/live2?query=products&target=mars&results=c&ihid=MRO&iid=HiRISE&pt=RDRV11&minlat=0.0&maxlat=10.0&westernlon=358&easternlon=5&loc=f
#   ```

# %% [markdown]
# ## Ask for a bouding box crossing the frame used by ODE [0:360], planetocentric

# %%
bbox = {
        'minlat': -0.5,
        'maxlat': 0.5,
        'westlon': 359.5,
        'eastlon': 0.5
    }

# %%
import ode
from importlib import reload
reload(ode)
# Out:
# <module 'ode' from '/Users/chbrandt/Coisas/repos/NEANIAS/notebooks/ode.py'>

# %%
req = ode.request_products(ode.API_URL, bbox=bbox)

# %%
req.status_code
# Out:
# 200

# %%
req.json()
# Out:
# {'ODEResults': {'Error': 'ODE V2.1.3 - ODE Rest requires either a combination of IHID, IID, and PT query parameters or PDSId query parameter or ODEID query parameter',
#   'QuerySummary': {'Date': '2020-09-14T08:26:19.831',
#    'easternlon': '0.5',
#    'loc': 'f',
#    'maxlat': '0.5',
#    'minlat': '-0.5',
#    'output': 'JSON',
#    'query': 'PRODUCT',
#    'Query_Elapsed_Time': '00:00:00.0156119',
#    'results': 'FMPC',
#    'westernlon': '359.5'},
#   'Status': 'ERROR'}}

# %%
req.json()['ODEResults']['Status']
# Out:
# 'ERROR'

# %%
req = ode.request_products(ode.API_URL, bbox=bbox, target='mars', host='mro', instr='hirise', ptype='rdrv11')

req.json()['ODEResults']['Status'] == 'ERROR' and req.json() or req.json()['ODEResults']['Count'] + ' products found'
# Out:
# '6 products found'

# %%
req.url
# Out:
# 'https://oderest.rsl.wustl.edu/live2/?query=product&results=fmpc&output=JSON&loc=f&minlat=-0.5&maxlat=0.5&westlon=359.5&eastlon=0.5&target=mars&ihid=mro&iid=hirise&pt=rdrv11'

# %%
req.json()
# Out:
# {'ODEResults': {'Count': '6',
#   'Products': {'Product': [{'BB_georeferenced': 'True',
#      'Center_georeferenced': 'True',
#      'Center_latitude': '-0.012',
#      'Center_longitude': '0.007',
#      'Comment': 'Center of Mars',
#      'Data_Set_Id': 'MRO-M-HIRISE-3-RDR-V1.1',
#      'Description': 'HiRISE projected and mosaicked product  HiRISE RDR V1.1 files has map projection data embedded in the header - please see SIS for more details.',
#      'Easternmost_longitude': '0.044',
#      'Emission_angle': '0.172008',
#      'External_url': 'http://www.uahirise.org/PSP_007361_1800',
#      'External_url2': 'jpip://hijpip.lpl.arizona.edu:8064/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.JP2',
#      'FilesURL': 'http://ode.rsl.wustl.edu/mars/productfiles.aspx?product_id=PSP_007361_1800_COLOR&product_idGeo=14284086',
#      'Footprint_C0_geometry': 'POLYGON ((0.044 -0.237, 0.025 -0.239, -0.03 0.212, -0.011 0.214, 0.044 -0.237))',
#      'Footprint_geometry': 'GEOMETRYCOLLECTION (POLYGON ((360 -0.034, 359.97 0.212, 359.989 0.214, 360 0.124, 360 -0.034)), POLYGON ((0.044 -0.237, 0.025 -0.239, 0 -0.034, 0 0.124, 0.044 -0.237)))',
#      'Footprint_GL_geometry': 'POLYGON ((0.044 -0.237, 0.025 -0.239, 359.97 0.212, 359.989 0.214, 0.044 -0.237))',
#      'Footprint_NP_geometry': 'MULTIPOLYGON EMPTY',
#      'Footprint_souce': 'PDS Archive Index Table',
#      'Footprint_SP_geometry': 'MULTIPOLYGON EMPTY',
#      'Footprints_cross_meridian': 'True',
#      'ihid': 'MRO',
#      'iid': 'HIRISE',
#      'Incidence_angle': '44.12436',
#      'LabelFileName': 'psp_007361_1800_color.lbl',
#      'LabelURL': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.LBL',
#      'Map_resolution': '118549.39504661',
#      'Map_scale': '0.5',
#      'Maximum_latitude': '0.214',
#      'Minimum_latitude': '-0.239',
#      'Observation_id': 'PSP_007361_1800',
#      'Observation_time': '2008-02-21T00:58:55.113',
#      'ODE_notes': {'ODE_note': ['NOTE: Product Type set by ODE',
#        'NOTE: Label keyword Orbit number value used for start orbit number value',
#        'NOTE: Label keyword Orbit number value used for stop orbit number value',
#        'NOTE: Map Resolution set from label map projection object',
#        'NOTE: Map scale from the label map projection object',
#        'NOTE: Observation time set to mid-point between start time and stop time',
#        'NOTE: Index Record:',
#        '"MROHR_0001","RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.JP2","MRO","HIRISE","PSP_007361_1800","PSP_007361_1800_COLOR","2  ","MARS                            ",  7361,"Primary Science Phase         ","Center of Mars                                                             ","2008-02-21T00:58:50     ","888022750:31012 ","2008-02-21T00:58:50     ","888022750:35907 ","2008-02-21T00:58:59     ","888022759:12115 ", 53697,  8672, 0.16470,44.1243, 43.9695, 269.136,3663.26, 269.138,  270.0000,  200.4429,   14.0629,  317.7460,   -0.0145,  359.9950,   1.63332,    34.809,   14.8174,"YES",   -0.2453,    0.2165,   -0.0650,    0.0797, 0.50,118549.398,"EQUIRECTANGULAR    ",  0.0,   0.000,     25125.5,      3486.5,   -0.2370,    0.0435,   -0.2392,    0.0252,    0.2115,   -0.0300,    0.2137,   -0.0110',
#        'NOTE: HIRISE location data updated from index table entry']},
#      'pdsid': 'PSP_007361_1800_COLOR',
#      'PDSVolume_Id': 'MROHR_0001',
#      'Phase_angle': '43.954011',
#      'Pole_state': 'none',
#      'Producer_id': 'UA',
#      'Product_creation_time': '2010-04-07T02:05:16.000',
#      'Product_files': {'Product_file': [{'Description': 'MAP PROJECTION FILE',
#         'FileName': 'DSMAP.CAT',
#         'KBytes': '7',
#         'Type': 'Referenced',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/CATALOG/DSMAP.CAT'},
#        {'Description': 'DESCRIPTION FILE',
#         'FileName': 'JP2INFO.TXT',
#         'KBytes': '9',
#         'Type': 'Referenced',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/DOCUMENT/JP2INFO.TXT'},
#        {'Description': 'ANNOTATED BROWSE',
#         'FileName': 'PSP_007361_1800_COLOR.ABROWSE.JPG',
#         'KBytes': '1036',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.abrowse.jpg'},
#        {'Description': 'BROWSE',
#         'FileName': 'PSP_007361_1800_COLOR.BROWSE.JPG',
#         'KBytes': '1191',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.browse.jpg'},
#        {'Description': 'PRODUCT DATA FILE',
#         'FileName': 'PSP_007361_1800_COLOR.JP2',
#         'KBytes': '189587',
#         'Type': 'Product',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.JP2'},
#        {'Description': 'PRODUCT LABEL FILE',
#         'FileName': 'PSP_007361_1800_COLOR.LBL',
#         'KBytes': '8',
#         'Type': 'Product',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.LBL'},
#        {'Description': 'QUICKLOOK JP2',
#         'FileName': 'PSP_007361_1800_COLOR.QLOOK.JP2',
#         'KBytes': '94329',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.QLOOK.JP2'},
#        {'Description': 'THUMBNAIL',
#         'FileName': 'PSP_007361_1800_COLOR.THUMB.JPG',
#         'KBytes': '342',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.thumb.jpg'},
#        {'Creation_date': '2015-10-17T03:49:09.983',
#         'Description': 'PRODUCT KML FILE <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'PSP_007361_1800_COLOR_LBL.KML',
#         'KBytes': '3',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/kmlfiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/psp/orb_007300_007399/psp_007361_1800/psp_007361_1800_color_lbl.kml'},
#        {'Creation_date': '2015-10-17T03:49:09.820',
#         'Description': 'PRODUCT FOOTPRINT SHAPEFILES (TAR.GZ) <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'PSP_007361_1800_COLOR_LBL.TAR.GZ',
#         'KBytes': '4',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/shapefiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/psp/orb_007300_007399/psp_007361_1800/psp_007361_1800_color_lbl.tar.gz'},
#        {'Creation_date': '2015-10-17T03:49:09.711',
#         'Description': 'PRODUCT FOOTPRINT SHAPEFILES (ZIP) <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'PSP_007361_1800_COLOR_LBL.ZIP',
#         'KBytes': '29',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/shapefiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/psp/orb_007300_007399/psp_007361_1800/psp_007361_1800_color_lbl.zip'},
#        {'Description': 'IRB BROWSE',
#         'FileName': 'PSP_007361_1800_IRB.NOMAP.BROWSE.JPG',
#         'KBytes': '3925',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_IRB.NOMAP.browse.jpg'},
#        {'Description': 'IRB JP2',
#         'FileName': 'PSP_007361_1800_IRB.NOMAP.JP2',
#         'KBytes': '196935',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_IRB.NOMAP.JP2'},
#        {'Description': 'IRB THUMBNAIL',
#         'FileName': 'PSP_007361_1800_IRB.NOMAP.THUMB.JPG',
#         'KBytes': '277',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_IRB.NOMAP.thumb.jpg'},
#        {'Description': 'ANNOTATED MERGED IRB BROWSE',
#         'FileName': 'PSP_007361_1800_MIRB.ABROWSE.JPG',
#         'KBytes': '4739',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.abrowse.jpg'},
#        {'Description': 'MERGED IRB BROWSE',
#         'FileName': 'PSP_007361_1800_MIRB.BROWSE.JPG',
#         'KBytes': '5315',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.browse.jpg'},
#        {'Description': 'MERGED IRB JP2',
#         'FileName': 'PSP_007361_1800_MIRB.JP2',
#         'KBytes': '424919',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.JP2'},
#        {'Description': 'MERGED IRB LABEL',
#         'FileName': 'PSP_007361_1800_MIRB.LBL',
#         'KBytes': '9',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.LBL'},
#        {'Description': 'MERGED IRB THUMBNAIL',
#         'FileName': 'PSP_007361_1800_MIRB.THUMB.JPG',
#         'KBytes': '324',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.thumb.jpg'},
#        {'Description': 'ANNOTATED MERGED RGB BROWSE',
#         'FileName': 'PSP_007361_1800_MRGB.ABROWSE.JPG',
#         'KBytes': '4738',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.abrowse.jpg'},
#        {'Description': 'MERGED RGB BROWSE',
#         'FileName': 'PSP_007361_1800_MRGB.BROWSE.JPG',
#         'KBytes': '5322',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.browse.jpg'},
#        {'Description': 'MERGED RGB JP2',
#         'FileName': 'PSP_007361_1800_MRGB.JP2',
#         'KBytes': '412242',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.JP2'},
#        {'Description': 'MERGED RGB LABEL',
#         'FileName': 'PSP_007361_1800_MRGB.LBL',
#         'KBytes': '9',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.LBL'},
#        {'Description': 'MERGED RGB THUMBNAIL',
#         'FileName': 'PSP_007361_1800_MRGB.THUMB.JPG',
#         'KBytes': '324',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.thumb.jpg'},
#        {'Description': 'RGB BROWSE',
#         'FileName': 'PSP_007361_1800_RGB.NOMAP.BROWSE.JPG',
#         'KBytes': '3404',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RGB.NOMAP.browse.jpg'},
#        {'Description': 'RGB JP2',
#         'FileName': 'PSP_007361_1800_RGB.NOMAP.JP2',
#         'KBytes': '193934',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RGB.NOMAP.JP2'},
#        {'Description': 'RGB THUMBNAIL',
#         'FileName': 'PSP_007361_1800_RGB.NOMAP.THUMB.JPG',
#         'KBytes': '245',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RGB.NOMAP.thumb.jpg'}]},
#      'Product_version_id': '2.0',
#      'ProductURL': 'http://ode.rsl.wustl.edu/mars/indexproductpage.aspx?product_id=PSP_007361_1800_COLOR&product_idGeo=14284086',
#      'pt': 'RDRV11',
#      'RelativePathtoVol': 'rdr\\psp\\orb_007300_007399\\psp_007361_1800\\',
#      'Solar_longitude': '34.80857',
#      'Solar_time': '14.81746',
#      'SpaceCraft_clock_start_count': '888022750:35907',
#      'SpaceCraft_clock_stop_count': '888022759:12115',
#      'Start_orbit_number': '7361',
#      'Stop_orbit_number': '7361',
#      'Target_name': 'MARS',
#      'UTC_start_time': '2008-02-21T00:58:50.769',
#      'UTC_stop_time': '2008-02-21T00:58:59.457',
#      'Westernmost_longitude': '359.97'},
#     {'BB_georeferenced': 'True',
#      'Center_georeferenced': 'True',
#      'Center_latitude': '-0.014',
#      'Center_longitude': '0.007',
#      'Comment': 'Center of Mars',
#      'Data_Set_Id': 'MRO-M-HIRISE-3-RDR-V1.1',
#      'Description': 'HiRISE projected and mosaicked product  HiRISE RDR V1.1 files has map projection data embedded in the header - please see SIS for more details.',
#      'Easternmost_longitude': '0.08',
#      'Emission_angle': '0.172712',
#      'External_url': 'http://www.uahirise.org/PSP_007361_1800',
#      'External_url2': 'jpip://hijpip.lpl.arizona.edu:8064/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.JP2',
#      'FilesURL': 'http://ode.rsl.wustl.edu/mars/productfiles.aspx?product_id=PSP_007361_1800_RED&product_idGeo=14284087',
#      'Footprint_C0_geometry': 'POLYGON ((0.08 -0.234, -0.011 -0.245, -0.065 0.206, 0.025 0.216, 0.08 -0.234))',
#      'Footprint_geometry': 'GEOMETRYCOLLECTION (POLYGON ((360 -0.244, 359.989 -0.245, 359.935 0.206, 360 0.213, 360 -0.244)), POLYGON ((0.08 -0.234, 0 -0.244, 0 0.213, 0.025 0.216, 0.08 -0.234)))',
#      'Footprint_GL_geometry': 'POLYGON ((0.08 -0.234, 359.989 -0.245, 359.935 0.206, 0.025 0.216, 0.08 -0.234))',
#      'Footprint_NP_geometry': 'MULTIPOLYGON EMPTY',
#      'Footprint_souce': 'PDS Archive Index Table',
#      'Footprint_SP_geometry': 'MULTIPOLYGON EMPTY',
#      'Footprints_cross_meridian': 'True',
#      'ihid': 'MRO',
#      'iid': 'HIRISE',
#      'Incidence_angle': '44.124317',
#      'LabelFileName': 'psp_007361_1800_red.lbl',
#      'LabelURL': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.LBL',
#      'Map_resolution': '118549.39504661',
#      'Map_scale': '0.5',
#      'Maximum_latitude': '0.216',
#      'Minimum_latitude': '-0.245',
#      'Observation_id': 'PSP_007361_1800',
#      'Observation_time': '2008-02-21T00:58:55.081',
#      'ODE_notes': {'ODE_note': ['NOTE: Product Type set by ODE',
#        'NOTE: Label keyword Orbit number value used for start orbit number value',
#        'NOTE: Label keyword Orbit number value used for stop orbit number value',
#        'NOTE: Map Resolution set from label map projection object',
#        'NOTE: Map scale from the label map projection object',
#        'NOTE: Observation time set to mid-point between start time and stop time',
#        'NOTE: Index Record:',
#        '"MROHR_0001","RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.JP2  ","MRO","HIRISE","PSP_007361_1800","PSP_007361_1800_RED  ","2  ","MARS                            ",  7361,"Primary Science Phase         ","Center of Mars                                                             ","2008-02-21T00:58:50     ","888022750:31012 ","2008-02-21T00:58:50     ","888022750:40231 ","2008-02-21T00:58:59     ","888022759:06983 ", 54736, 17209, 0.16470,44.1243, 43.9695, 269.136,3663.26, 269.138,  270.0000,  200.4428,   14.0629,  317.7460,   -0.0145,  359.9950,   1.63332,    34.809,   14.8174,"YES",   -0.2453,    0.2165,   -0.0650,    0.0797, 0.50,118549.398,"EQUIRECTANGULAR    ",  0.0,   0.000,     25661.5,      7757.5,   -0.2343,    0.0797,   -0.2453,   -0.0110,    0.2055,   -0.0650,    0.2164,    0.0249',
#        'NOTE: HIRISE location data updated from index table entry']},
#      'pdsid': 'PSP_007361_1800_RED',
#      'PDSVolume_Id': 'MROHR_0001',
#      'Phase_angle': '43.953009',
#      'Pole_state': 'none',
#      'Producer_id': 'UA',
#      'Product_creation_time': '2010-04-07T02:11:12.000',
#      'Product_files': {'Product_file': [{'Description': 'MAP PROJECTION FILE',
#         'FileName': 'DSMAP.CAT',
#         'KBytes': '7',
#         'Type': 'Referenced',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/CATALOG/DSMAP.CAT'},
#        {'Description': 'DESCRIPTION FILE',
#         'FileName': 'JP2INFO.TXT',
#         'KBytes': '9',
#         'Type': 'Referenced',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/DOCUMENT/JP2INFO.TXT'},
#        {'Description': 'ANNOTATED MERGED IRB BROWSE',
#         'FileName': 'PSP_007361_1800_MIRB.ABROWSE.JPG',
#         'KBytes': '4739',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.abrowse.jpg'},
#        {'Description': 'MERGED IRB BROWSE',
#         'FileName': 'PSP_007361_1800_MIRB.BROWSE.JPG',
#         'KBytes': '5315',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.browse.jpg'},
#        {'Description': 'MERGED IRB JP2',
#         'FileName': 'PSP_007361_1800_MIRB.JP2',
#         'KBytes': '424919',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.JP2'},
#        {'Description': 'MERGED IRB LABEL',
#         'FileName': 'PSP_007361_1800_MIRB.LBL',
#         'KBytes': '9',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.LBL'},
#        {'Description': 'MERGED IRB THUMBNAIL',
#         'FileName': 'PSP_007361_1800_MIRB.THUMB.JPG',
#         'KBytes': '324',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.thumb.jpg'},
#        {'Description': 'ANNOTATED MERGED RGB BROWSE',
#         'FileName': 'PSP_007361_1800_MRGB.ABROWSE.JPG',
#         'KBytes': '4738',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.abrowse.jpg'},
#        {'Description': 'MERGED RGB BROWSE',
#         'FileName': 'PSP_007361_1800_MRGB.BROWSE.JPG',
#         'KBytes': '5322',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.browse.jpg'},
#        {'Description': 'MERGED RGB JP2',
#         'FileName': 'PSP_007361_1800_MRGB.JP2',
#         'KBytes': '412242',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.JP2'},
#        {'Description': 'MERGED RGB LABEL',
#         'FileName': 'PSP_007361_1800_MRGB.LBL',
#         'KBytes': '9',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.LBL'},
#        {'Description': 'MERGED RGB THUMBNAIL',
#         'FileName': 'PSP_007361_1800_MRGB.THUMB.JPG',
#         'KBytes': '324',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.thumb.jpg'},
#        {'Description': 'ANNOTATED BROWSE',
#         'FileName': 'PSP_007361_1800_RED.ABROWSE.JPG',
#         'KBytes': '4490',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.abrowse.jpg'},
#        {'Description': 'BROWSE',
#         'FileName': 'PSP_007361_1800_RED.BROWSE.JPG',
#         'KBytes': '5007',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.browse.jpg'},
#        {'Description': 'PRODUCT DATA FILE',
#         'FileName': 'PSP_007361_1800_RED.JP2',
#         'KBytes': '454599',
#         'Type': 'Product',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.JP2'},
#        {'Description': 'PRODUCT LABEL FILE',
#         'FileName': 'PSP_007361_1800_RED.LBL',
#         'KBytes': '9',
#         'Type': 'Product',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.LBL'},
#        {'Description': 'GREYSCALE BROWSE',
#         'FileName': 'PSP_007361_1800_RED.NOMAP.BROWSE.JPG',
#         'KBytes': '12448',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.NOMAP.browse.jpg'},
#        {'Description': 'GREYSCALE JP2',
#         'FileName': 'PSP_007361_1800_RED.NOMAP.JP2',
#         'KBytes': '268153',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.NOMAP.JP2'},
#        {'Description': 'GREYSCALE THUMBNAIL',
#         'FileName': 'PSP_007361_1800_RED.NOMAP.THUMB.JPG',
#         'KBytes': '886',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.NOMAP.thumb.jpg'},
#        {'Description': 'QUICKLOOK JP2',
#         'FileName': 'PSP_007361_1800_RED.QLOOK.JP2',
#         'KBytes': '236061',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.QLOOK.JP2'},
#        {'Description': 'THUMBNAIL',
#         'FileName': 'PSP_007361_1800_RED.THUMB.JPG',
#         'KBytes': '323',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.thumb.jpg'},
#        {'Creation_date': '2015-10-17T03:49:16.168',
#         'Description': 'PRODUCT KML FILE <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'PSP_007361_1800_RED_LBL.KML',
#         'KBytes': '3',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/kmlfiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/psp/orb_007300_007399/psp_007361_1800/psp_007361_1800_red_lbl.kml'},
#        {'Creation_date': '2015-10-17T03:49:15.819',
#         'Description': 'PRODUCT FOOTPRINT SHAPEFILES (TAR.GZ) <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'PSP_007361_1800_RED_LBL.TAR.GZ',
#         'KBytes': '4',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/shapefiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/psp/orb_007300_007399/psp_007361_1800/psp_007361_1800_red_lbl.tar.gz'},
#        {'Creation_date': '2015-10-17T03:49:15.605',
#         'Description': 'PRODUCT FOOTPRINT SHAPEFILES (ZIP) <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'PSP_007361_1800_RED_LBL.ZIP',
#         'KBytes': '29',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/shapefiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/psp/orb_007300_007399/psp_007361_1800/psp_007361_1800_red_lbl.zip'}]},
#      'Product_version_id': '2.0',
#      'ProductURL': 'http://ode.rsl.wustl.edu/mars/indexproductpage.aspx?product_id=PSP_007361_1800_RED&product_idGeo=14284087',
#      'pt': 'RDRV11',
#      'RelativePathtoVol': 'rdr\\psp\\orb_007300_007399\\psp_007361_1800\\',
#      'Solar_longitude': '34.80857',
#      'Solar_time': '14.81746',
#      'SpaceCraft_clock_start_count': '888022750:40231',
#      'SpaceCraft_clock_stop_count': '888022759:06983',
#      'Start_orbit_number': '7361',
#      'Stop_orbit_number': '7361',
#      'Target_name': 'MARS',
#      'UTC_start_time': '2008-02-21T00:58:50.835',
#      'UTC_stop_time': '2008-02-21T00:58:59.328',
#      'Westernmost_longitude': '359.935'},
#     {'BB_georeferenced': 'True',
#      'Center_georeferenced': 'True',
#      'Center_latitude': '0.101',
#      'Center_longitude': '359.92',
#      'Comment': 'Meridiani Planum',
#      'Data_Set_Id': 'MRO-M-HIRISE-3-RDR-V1.1',
#      'Description': 'HiRISE projected and mosaicked product  HiRISE RDR V1.1 files has map projection data embedded in the header - please see SIS for more details.',
#      'Easternmost_longitude': '359.942',
#      'Emission_angle': '5.129297',
#      'External_url': 'http://www.uahirise.org/ESP_023817_1800',
#      'External_url2': 'jpip://hijpip.lpl.arizona.edu:8064/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_COLOR.JP2',
#      'FilesURL': 'http://ode.rsl.wustl.edu/mars/productfiles.aspx?product_id=ESP_023817_1800_COLOR&product_idGeo=17973988',
#      'Footprint_C0_geometry': 'POLYGON ((-0.058 0, -0.077 -0.002, -0.101 0.202, -0.082 0.204, -0.058 0))',
#      'Footprint_geometry': 'POLYGON ((359.942 0, 359.923 -0.002, 359.899 0.202, 359.918 0.204, 359.942 0))',
#      'Footprint_GL_geometry': 'POLYGON ((359.942 0, 359.923 -0.002, 359.899 0.202, 359.918 0.204, 359.942 0))',
#      'Footprint_NP_geometry': 'MULTIPOLYGON EMPTY',
#      'Footprint_souce': 'PDS Archive Index Table',
#      'Footprint_SP_geometry': 'MULTIPOLYGON EMPTY',
#      'Footprints_cross_meridian': 'False',
#      'ihid': 'MRO',
#      'iid': 'HIRISE',
#      'Incidence_angle': '32.812105',
#      'LabelFileName': 'esp_023817_1800_color.lbl',
#      'LabelURL': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_COLOR.LBL',
#      'Map_resolution': '118549.39504661',
#      'Map_scale': '0.5',
#      'Maximum_latitude': '0.204',
#      'Minimum_latitude': '-0.002',
#      'Observation_id': 'ESP_023817_1800',
#      'Observation_time': '2011-08-26T08:15:15.664',
#      'ODE_notes': {'ODE_note': ['NOTE: Product Type set by ODE',
#        'NOTE: Label keyword Orbit number value used for start orbit number value',
#        'NOTE: Label keyword Orbit number value used for stop orbit number value',
#        'NOTE: Map Resolution set from label map projection object',
#        'NOTE: Map scale from the label map projection object',
#        'NOTE: Observation time set to mid-point between start time and stop time',
#        'NOTE: Index Record:',
#        '"MROHR_0001","RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_COLOR.JP2","MRO","HIRISE","ESP_023817_1800","ESP_023817_1800_COLOR","1  ","MARS                            ", 23817,"Extended Science Phase        ","Meridiani Planum                                                           ","2011-08-26T08:15:13     ","998813746:00546 ","2011-08-26T08:15:13     ","998813746:03601 ","2011-08-26T08:15:17     ","998813750:05091 ", 24445,  5060, 5.12739,32.8120, 37.9394, 269.406,3663.86, 270.506,  270.0000,  172.5870,   -3.9241,  327.3320,    0.1476,    0.2959,   1.53444,   350.748,   14.1726,"NO ",   -0.0066,    0.2085,   -0.1370,   -0.0220, 0.50,118549.398,"EQUIRECTANGULAR    ",  0.0,   0.000,     24173.5,     11944.5,    0.0002,   -0.0580,   -0.0020,   -0.0770,    0.2020,   -0.1010,    0.2042,   -0.0820',
#        'NOTE: HIRISE location data updated from index table entry']},
#      'pdsid': 'ESP_023817_1800_COLOR',
#      'PDSVolume_Id': 'MROHR_0001',
#      'Phase_angle': '37.941394',
#      'Pole_state': 'none',
#      'Producer_id': 'UA',
#      'Product_creation_time': '2011-09-01T16:36:21.000',
#      'Product_files': {'Product_file': [{'Description': 'MAP PROJECTION FILE',
#         'FileName': 'DSMAP.CAT',
#         'KBytes': '7',
#         'Type': 'Referenced',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/CATALOG/DSMAP.CAT'},
#        {'Description': 'ANNOTATED BROWSE',
#         'FileName': 'ESP_023817_1800_COLOR.ABROWSE.JPG',
#         'KBytes': '1392',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_COLOR.abrowse.jpg'},
#        {'Description': 'BROWSE',
#         'FileName': 'ESP_023817_1800_COLOR.BROWSE.JPG',
#         'KBytes': '1614',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_COLOR.browse.jpg'},
#        {'Description': 'PRODUCT DATA FILE',
#         'FileName': 'ESP_023817_1800_COLOR.JP2',
#         'KBytes': '98953',
#         'Type': 'Product',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_COLOR.JP2'},
#        {'Description': 'PRODUCT LABEL FILE',
#         'FileName': 'ESP_023817_1800_COLOR.LBL',
#         'KBytes': '8',
#         'Type': 'Product',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_COLOR.LBL'},
#        {'Description': 'QUICKLOOK JP2',
#         'FileName': 'ESP_023817_1800_COLOR.QLOOK.JP2',
#         'KBytes': '31126',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_COLOR.QLOOK.JP2'},
#        {'Description': 'THUMBNAIL',
#         'FileName': 'ESP_023817_1800_COLOR.THUMB.JPG',
#         'KBytes': '466',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_COLOR.thumb.jpg'},
#        {'Creation_date': '2015-10-19T23:47:15.309',
#         'Description': 'PRODUCT KML FILE <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'ESP_023817_1800_COLOR_LBL.KML',
#         'KBytes': '3',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/kmlfiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/esp/orb_023800_023899/esp_023817_1800/esp_023817_1800_color_lbl.kml'},
#        {'Creation_date': '2015-10-19T23:47:14.954',
#         'Description': 'PRODUCT FOOTPRINT SHAPEFILES (TAR.GZ) <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'ESP_023817_1800_COLOR_LBL.TAR.GZ',
#         'KBytes': '4',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/shapefiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/esp/orb_023800_023899/esp_023817_1800/esp_023817_1800_color_lbl.tar.gz'},
#        {'Creation_date': '2015-10-19T23:47:14.846',
#         'Description': 'PRODUCT FOOTPRINT SHAPEFILES (ZIP) <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'ESP_023817_1800_COLOR_LBL.ZIP',
#         'KBytes': '26',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/shapefiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/esp/orb_023800_023899/esp_023817_1800/esp_023817_1800_color_lbl.zip'},
#        {'Description': 'IRB BROWSE',
#         'FileName': 'ESP_023817_1800_IRB.NOMAP.BROWSE.JPG',
#         'KBytes': '2055',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_IRB.NOMAP.browse.jpg'},
#        {'Description': 'IRB JP2',
#         'FileName': 'ESP_023817_1800_IRB.NOMAP.JP2',
#         'KBytes': '113304',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_IRB.NOMAP.JP2'},
#        {'Description': 'IRB THUMBNAIL',
#         'FileName': 'ESP_023817_1800_IRB.NOMAP.THUMB.JPG',
#         'KBytes': '125',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_IRB.NOMAP.thumb.jpg'},
#        {'Description': 'ANNOTATED MERGED IRB BROWSE',
#         'FileName': 'ESP_023817_1800_MIRB.ABROWSE.JPG',
#         'KBytes': '3716',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MIRB.abrowse.jpg'},
#        {'Description': 'MERGED IRB BROWSE',
#         'FileName': 'ESP_023817_1800_MIRB.BROWSE.JPG',
#         'KBytes': '4206',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MIRB.browse.jpg'},
#        {'Description': 'MERGED IRB JP2',
#         'FileName': 'ESP_023817_1800_MIRB.JP2',
#         'KBytes': '218972',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MIRB.JP2'},
#        {'Description': 'MERGED IRB LABEL',
#         'FileName': 'ESP_023817_1800_MIRB.LBL',
#         'KBytes': '9',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MIRB.LBL'},
#        {'Description': 'MERGED IRB THUMBNAIL',
#         'FileName': 'ESP_023817_1800_MIRB.THUMB.JPG',
#         'KBytes': '234',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MIRB.thumb.jpg'},
#        {'Description': 'ANNOTATED MERGED RGB BROWSE',
#         'FileName': 'ESP_023817_1800_MRGB.ABROWSE.JPG',
#         'KBytes': '3715',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MRGB.abrowse.jpg'},
#        {'Description': 'MERGED RGB BROWSE',
#         'FileName': 'ESP_023817_1800_MRGB.BROWSE.JPG',
#         'KBytes': '4208',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MRGB.browse.jpg'},
#        {'Description': 'MERGED RGB JP2',
#         'FileName': 'ESP_023817_1800_MRGB.JP2',
#         'KBytes': '210023',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MRGB.JP2'},
#        {'Description': 'MERGED RGB LABEL',
#         'FileName': 'ESP_023817_1800_MRGB.LBL',
#         'KBytes': '9',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MRGB.LBL'},
#        {'Description': 'MERGED RGB THUMBNAIL',
#         'FileName': 'ESP_023817_1800_MRGB.THUMB.JPG',
#         'KBytes': '234',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MRGB.thumb.jpg'},
#        {'Description': 'RGB BROWSE',
#         'FileName': 'ESP_023817_1800_RGB.NOMAP.BROWSE.JPG',
#         'KBytes': '1982',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RGB.NOMAP.browse.jpg'},
#        {'Description': 'RGB JP2',
#         'FileName': 'ESP_023817_1800_RGB.NOMAP.JP2',
#         'KBytes': '112189',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RGB.NOMAP.JP2'},
#        {'Description': 'RGB THUMBNAIL',
#         'FileName': 'ESP_023817_1800_RGB.NOMAP.THUMB.JPG',
#         'KBytes': '119',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RGB.NOMAP.thumb.jpg'},
#        {'Description': 'DESCRIPTION FILE',
#         'FileName': 'JP2INFO.TXT',
#         'KBytes': '9',
#         'Type': 'Referenced',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/DOCUMENT/JP2INFO.TXT'}]},
#      'Product_version_id': '1.0',
#      'ProductURL': 'http://ode.rsl.wustl.edu/mars/indexproductpage.aspx?product_id=ESP_023817_1800_COLOR&product_idGeo=17973988',
#      'pt': 'RDRV11',
#      'RelativePathtoVol': 'rdr\\esp\\orb_023800_023899\\esp_023817_1800\\',
#      'Solar_longitude': '350.748489',
#      'Solar_time': '14.17262',
#      'SpaceCraft_clock_start_count': '998813746:03601',
#      'SpaceCraft_clock_stop_count': '998813750:05091',
#      'Start_orbit_number': '23817',
#      'Stop_orbit_number': '23817',
#      'Target_name': 'MARS',
#      'UTC_start_time': '2011-08-26T08:15:13.627',
#      'UTC_stop_time': '2011-08-26T08:15:17.701',
#      'Westernmost_longitude': '359.899'},
#     {'BB_georeferenced': 'True',
#      'Center_georeferenced': 'True',
#      'Center_latitude': '0.101',
#      'Center_longitude': '359.921',
#      'Comment': 'Meridiani Planum',
#      'Data_Set_Id': 'MRO-M-HIRISE-3-RDR-V1.1',
#      'Description': 'HiRISE projected and mosaicked product  HiRISE RDR V1.1 files has map projection data embedded in the header - please see SIS for more details.',
#      'Easternmost_longitude': '359.978',
#      'Emission_angle': '5.129825',
#      'External_url': 'http://www.uahirise.org/ESP_023817_1800',
#      'External_url2': 'jpip://hijpip.lpl.arizona.edu:8064/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.JP2',
#      'FilesURL': 'http://ode.rsl.wustl.edu/mars/productfiles.aspx?product_id=ESP_023817_1800_RED&product_idGeo=17973989',
#      'Footprint_C0_geometry': 'POLYGON ((-0.022 0.004, -0.113 -0.007, -0.137 0.197, -0.046 0.208, -0.022 0.004))',
#      'Footprint_geometry': 'POLYGON ((359.978 0.004, 359.887 -0.007, 359.863 0.197, 359.954 0.208, 359.978 0.004))',
#      'Footprint_GL_geometry': 'POLYGON ((359.978 0.004, 359.887 -0.007, 359.863 0.197, 359.954 0.208, 359.978 0.004))',
#      'Footprint_NP_geometry': 'MULTIPOLYGON EMPTY',
#      'Footprint_souce': 'PDS Archive Index Table',
#      'Footprint_SP_geometry': 'MULTIPOLYGON EMPTY',
#      'Footprints_cross_meridian': 'False',
#      'ihid': 'MRO',
#      'iid': 'HIRISE',
#      'Incidence_angle': '32.812091',
#      'LabelFileName': 'esp_023817_1800_red.lbl',
#      'LabelURL': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.LBL',
#      'Map_resolution': '118549.39504661',
#      'Map_scale': '0.5',
#      'Maximum_latitude': '0.208',
#      'Minimum_latitude': '-0.007',
#      'Observation_id': 'ESP_023817_1800',
#      'Observation_time': '2011-08-26T08:15:15.659',
#      'ODE_notes': {'ODE_note': ['NOTE: Product Type set by ODE',
#        'NOTE: Label keyword Orbit number value used for start orbit number value',
#        'NOTE: Label keyword Orbit number value used for stop orbit number value',
#        'NOTE: Map Resolution set from label map projection object',
#        'NOTE: Map scale from the label map projection object',
#        'NOTE: Observation time set to mid-point between start time and stop time',
#        'NOTE: Index Record:',
#        '"MROHR_0001","RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.JP2  ","MRO","HIRISE","ESP_023817_1800","ESP_023817_1800_RED  ","1  ","MARS                            ", 23817,"Extended Science Phase        ","Meridiani Planum                                                           ","2011-08-26T08:15:13     ","998813746:00546 ","2011-08-26T08:15:13     ","998813746:09819 ","2011-08-26T08:15:17     ","998813750:01620 ", 25491, 13682, 5.12739,32.8120, 37.9394, 269.406,3663.86, 270.506,  270.0000,  172.5868,   -3.9241,  327.3320,    0.1476,    0.2959,   1.53444,   350.748,   14.1726,"NO ",   -0.0066,    0.2085,   -0.1370,   -0.0220, 0.50,118549.398,"EQUIRECTANGULAR    ",  0.0,   0.000,     24712.5,     16261.5,    0.0045,   -0.0220,   -0.0066,   -0.1130,    0.1974,   -0.1370,    0.2084,   -0.0460',
#        'NOTE: HIRISE location data updated from index table entry']},
#      'pdsid': 'ESP_023817_1800_RED',
#      'PDSVolume_Id': 'MROHR_0001',
#      'Phase_angle': '37.941905',
#      'Pole_state': 'none',
#      'Producer_id': 'UA',
#      'Product_creation_time': '2011-09-01T02:08:15.000',
#      'Product_files': {'Product_file': [{'Description': 'MAP PROJECTION FILE',
#         'FileName': 'DSMAP.CAT',
#         'KBytes': '7',
#         'Type': 'Referenced',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/CATALOG/DSMAP.CAT'},
#        {'Description': 'ANNOTATED MERGED IRB BROWSE',
#         'FileName': 'ESP_023817_1800_MIRB.ABROWSE.JPG',
#         'KBytes': '3716',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MIRB.abrowse.jpg'},
#        {'Description': 'MERGED IRB BROWSE',
#         'FileName': 'ESP_023817_1800_MIRB.BROWSE.JPG',
#         'KBytes': '4206',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MIRB.browse.jpg'},
#        {'Description': 'MERGED IRB JP2',
#         'FileName': 'ESP_023817_1800_MIRB.JP2',
#         'KBytes': '218972',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MIRB.JP2'},
#        {'Description': 'MERGED IRB LABEL',
#         'FileName': 'ESP_023817_1800_MIRB.LBL',
#         'KBytes': '9',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MIRB.LBL'},
#        {'Description': 'MERGED IRB THUMBNAIL',
#         'FileName': 'ESP_023817_1800_MIRB.THUMB.JPG',
#         'KBytes': '234',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MIRB.thumb.jpg'},
#        {'Description': 'ANNOTATED MERGED RGB BROWSE',
#         'FileName': 'ESP_023817_1800_MRGB.ABROWSE.JPG',
#         'KBytes': '3715',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MRGB.abrowse.jpg'},
#        {'Description': 'MERGED RGB BROWSE',
#         'FileName': 'ESP_023817_1800_MRGB.BROWSE.JPG',
#         'KBytes': '4208',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MRGB.browse.jpg'},
#        {'Description': 'MERGED RGB JP2',
#         'FileName': 'ESP_023817_1800_MRGB.JP2',
#         'KBytes': '210023',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MRGB.JP2'},
#        {'Description': 'MERGED RGB LABEL',
#         'FileName': 'ESP_023817_1800_MRGB.LBL',
#         'KBytes': '9',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MRGB.LBL'},
#        {'Description': 'MERGED RGB THUMBNAIL',
#         'FileName': 'ESP_023817_1800_MRGB.THUMB.JPG',
#         'KBytes': '234',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_MRGB.thumb.jpg'},
#        {'Description': 'ANNOTATED BROWSE',
#         'FileName': 'ESP_023817_1800_RED.ABROWSE.JPG',
#         'KBytes': '3611',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.abrowse.jpg'},
#        {'Description': 'BROWSE',
#         'FileName': 'ESP_023817_1800_RED.BROWSE.JPG',
#         'KBytes': '4076',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.browse.jpg'},
#        {'Description': 'PRODUCT DATA FILE',
#         'FileName': 'ESP_023817_1800_RED.JP2',
#         'KBytes': '219534',
#         'Type': 'Product',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.JP2'},
#        {'Description': 'PRODUCT LABEL FILE',
#         'FileName': 'ESP_023817_1800_RED.LBL',
#         'KBytes': '9',
#         'Type': 'Product',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.LBL'},
#        {'Description': 'GREYSCALE BROWSE',
#         'FileName': 'ESP_023817_1800_RED.NOMAP.BROWSE.JPG',
#         'KBytes': '6443',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.NOMAP.browse.jpg'},
#        {'Description': 'GREYSCALE JP2',
#         'FileName': 'ESP_023817_1800_RED.NOMAP.JP2',
#         'KBytes': '132211',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.NOMAP.JP2'},
#        {'Description': 'GREYSCALE THUMBNAIL',
#         'FileName': 'ESP_023817_1800_RED.NOMAP.THUMB.JPG',
#         'KBytes': '421',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.NOMAP.thumb.jpg'},
#        {'Description': 'QUICKLOOK JP2',
#         'FileName': 'ESP_023817_1800_RED.QLOOK.JP2',
#         'KBytes': '87412',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.QLOOK.JP2'},
#        {'Description': 'THUMBNAIL',
#         'FileName': 'ESP_023817_1800_RED.THUMB.JPG',
#         'KBytes': '242',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.thumb.jpg'},
#        {'Creation_date': '2015-10-19T23:47:21.453',
#         'Description': 'PRODUCT KML FILE <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'ESP_023817_1800_RED_LBL.KML',
#         'KBytes': '3',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/kmlfiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/esp/orb_023800_023899/esp_023817_1800/esp_023817_1800_red_lbl.kml'},
#        {'Creation_date': '2015-10-19T23:47:21.282',
#         'Description': 'PRODUCT FOOTPRINT SHAPEFILES (TAR.GZ) <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'ESP_023817_1800_RED_LBL.TAR.GZ',
#         'KBytes': '4',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/shapefiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/esp/orb_023800_023899/esp_023817_1800/esp_023817_1800_red_lbl.tar.gz'},
#        {'Creation_date': '2015-10-19T23:47:21.143',
#         'Description': 'PRODUCT FOOTPRINT SHAPEFILES (ZIP) <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'ESP_023817_1800_RED_LBL.ZIP',
#         'KBytes': '26',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/shapefiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/esp/orb_023800_023899/esp_023817_1800/esp_023817_1800_red_lbl.zip'},
#        {'Description': 'DESCRIPTION FILE',
#         'FileName': 'JP2INFO.TXT',
#         'KBytes': '9',
#         'Type': 'Referenced',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/DOCUMENT/JP2INFO.TXT'}]},
#      'Product_version_id': '1.0',
#      'ProductURL': 'http://ode.rsl.wustl.edu/mars/indexproductpage.aspx?product_id=ESP_023817_1800_RED&product_idGeo=17973989',
#      'pt': 'RDRV11',
#      'RelativePathtoVol': 'rdr\\esp\\orb_023800_023899\\esp_023817_1800\\',
#      'Solar_longitude': '350.748489',
#      'Solar_time': '14.17261',
#      'SpaceCraft_clock_start_count': '998813746:09819',
#      'SpaceCraft_clock_stop_count': '998813750:01620',
#      'Start_orbit_number': '23817',
#      'Stop_orbit_number': '23817',
#      'Target_name': 'MARS',
#      'UTC_start_time': '2011-08-26T08:15:13.722',
#      'UTC_stop_time': '2011-08-26T08:15:17.597',
#      'Westernmost_longitude': '359.863'},
#     {'BB_georeferenced': 'True',
#      'Center_georeferenced': 'True',
#      'Center_latitude': '-0.002',
#      'Center_longitude': '359.995',
#      'Comment': 'Center of Mars',
#      'Data_Set_Id': 'MRO-M-HIRISE-3-RDR-V1.1',
#      'Description': 'HiRISE projected and mosaicked product  HiRISE RDR V1.1 files has map projection data embedded in the header - please see SIS for more details.',
#      'Easternmost_longitude': '0.023',
#      'Emission_angle': '22.251847',
#      'External_url': 'http://www.uahirise.org/ESP_041909_1800',
#      'External_url2': 'jpip://hijpip.lpl.arizona.edu:8064/PDS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_COLOR.JP2',
#      'FilesURL': 'http://ode.rsl.wustl.edu/mars/productfiles.aspx?product_id=ESP_041909_1800_COLOR&product_idGeo=24728277',
#      'Footprint_C0_geometry': 'POLYGON ((0.023 -0.146, 0.001 -0.149, -0.032 0.142, -0.011 0.145, 0.023 -0.146))',
#      'Footprint_geometry': 'GEOMETRYCOLLECTION (POLYGON ((360 -0.14, 359.968 0.142, 359.989 0.145, 360 0.051, 360 -0.14)), POLYGON ((0.023 -0.146, 0.001 -0.149, 0 -0.14, 0 0.051, 0.023 -0.146)))',
# ...
#        {'Description': 'MERGED IRB BROWSE',
#         'FileName': 'ESP_041909_1800_MIRB.BROWSE.JPG',
#         'KBytes': '4754',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MIRB.browse.jpg'},
#        {'Description': 'MERGED IRB JP2',
#         'FileName': 'ESP_041909_1800_MIRB.JP2',
#         'KBytes': '272459',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MIRB.JP2'},
#        {'Description': 'MERGED IRB LABEL',
#         'FileName': 'ESP_041909_1800_MIRB.LBL',
#         'KBytes': '9',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MIRB.LBL'},
#        {'Description': 'MERGED IRB THUMBNAIL',
#         'FileName': 'ESP_041909_1800_MIRB.THUMB.JPG',
#         'KBytes': '286',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MIRB.thumb.jpg'},
#        {'Description': 'ANNOTATED MERGED RGB BROWSE',
#         'FileName': 'ESP_041909_1800_MRGB.ABROWSE.JPG',
#         'KBytes': '4240',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MRGB.abrowse.jpg'},
#        {'Description': 'MERGED RGB BROWSE',
#         'FileName': 'ESP_041909_1800_MRGB.BROWSE.JPG',
#         'KBytes': '4748',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MRGB.browse.jpg'},
#        {'Description': 'MERGED RGB JP2',
#         'FileName': 'ESP_041909_1800_MRGB.JP2',
#         'KBytes': '268965',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MRGB.JP2'},
#        {'Description': 'MERGED RGB LABEL',
#         'FileName': 'ESP_041909_1800_MRGB.LBL',
#         'KBytes': '9',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MRGB.LBL'},
#        {'Description': 'MERGED RGB THUMBNAIL',
#         'FileName': 'ESP_041909_1800_MRGB.THUMB.JPG',
#         'KBytes': '286',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MRGB.thumb.jpg'},
#        {'Description': 'RGB BROWSE',
#         'FileName': 'ESP_041909_1800_RGB.NOMAP.BROWSE.JPG',
#         'KBytes': '2257',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RGB.NOMAP.browse.jpg'},
#        {'Description': 'RGB JP2',
#         'FileName': 'ESP_041909_1800_RGB.NOMAP.JP2',
#         'KBytes': '121053',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RGB.NOMAP.JP2'},
#        {'Description': 'RGB THUMBNAIL',
#         'FileName': 'ESP_041909_1800_RGB.NOMAP.THUMB.JPG',
#         'KBytes': '149',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RGB.NOMAP.thumb.jpg'},
#        {'Description': 'DESCRIPTION FILE',
#         'FileName': 'JP2INFO.TXT',
#         'KBytes': '9',
#         'Type': 'Referenced',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/DOCUMENT/JP2INFO.TXT'}]},
#      'Product_version_id': '1.0',
#      'ProductURL': 'http://ode.rsl.wustl.edu/mars/indexproductpage.aspx?product_id=ESP_041909_1800_COLOR&product_idGeo=24728277',
#      'pt': 'RDRV11',
#      'RelativePathtoVol': 'rdr\\esp\\orb_041900_041999\\esp_041909_1800\\',
#      'Solar_longitude': '8.638808',
#      'Solar_time': '14.37352',
#      'SpaceCraft_clock_start_count': '1120613486:26106',
#      'SpaceCraft_clock_stop_count': '1120613492:04560',
#      'Start_orbit_number': '41909',
#      'Stop_orbit_number': '41909',
#      'Target_name': 'MARS',
#      'UTC_start_time': '2015-07-06T01:30:45.415',
#      'UTC_stop_time': '2015-07-06T01:30:51.141',
#      'Westernmost_longitude': '359.968'},
#     {'BB_georeferenced': 'True',
#      'Center_georeferenced': 'True',
#      'Center_latitude': '-0.003',
#      'Center_longitude': '0.001',
#      'Comment': 'Center of Mars',
#      'Data_Set_Id': 'MRO-M-HIRISE-3-RDR-V1.1',
#      'Description': 'HiRISE projected and mosaicked product  HiRISE RDR V1.1 files has map projection data embedded in the header - please see SIS for more details.',
#      'Easternmost_longitude': '0.065',
#      'Emission_angle': '22.191232',
#      'External_url': 'http://www.uahirise.org/ESP_041909_1800',
#      'External_url2': 'jpip://hijpip.lpl.arizona.edu:8064/PDS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.JP2',
#      'FilesURL': 'http://ode.rsl.wustl.edu/mars/productfiles.aspx?product_id=ESP_041909_1800_RED&product_idGeo=24728280',
#      'Footprint_C0_geometry': 'POLYGON ((0.065 -0.143, -0.03 -0.155, -0.063 0.137, 0.031 0.148, 0.065 -0.143))',
#      'Footprint_geometry': 'GEOMETRYCOLLECTION (POLYGON ((360 -0.151, 359.97 -0.155, 359.937 0.137, 360 0.144, 360 -0.151)), POLYGON ((0.065 -0.143, 0 -0.151, 0 0.144, 0.031 0.148, 0.065 -0.143)))',
#      'Footprint_GL_geometry': 'POLYGON ((0.065 -0.143, 359.97 -0.155, 359.937 0.137, 0.031 0.148, 0.065 -0.143))',
#      'Footprint_NP_geometry': 'MULTIPOLYGON EMPTY',
#      'Footprint_souce': 'PDS Archive Index Table',
#      'Footprint_SP_geometry': 'MULTIPOLYGON EMPTY',
#      'Footprints_cross_meridian': 'True',
#      'ihid': 'MRO',
#      'iid': 'HIRISE',
#      'Incidence_angle': '35.772163',
#      'LabelFileName': 'esp_041909_1800_red.lbl',
#      'LabelURL': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.LBL',
#      'Map_resolution': '118549.39504661',
#      'Map_scale': '0.5',
#      'Maximum_latitude': '0.148',
#      'Minimum_latitude': '-0.155',
#      'Observation_id': 'ESP_041909_1800',
#      'Observation_time': '2015-07-06T01:30:48.245',
#      'ODE_notes': {'ODE_note': ['NOTE: Product Type set by ODE',
#        'NOTE: Label keyword Orbit number value used for start orbit number value',
#        'NOTE: Label keyword Orbit number value used for stop orbit number value',
#        'NOTE: Map Resolution set from label map projection object',
#        'NOTE: Map scale from the label map projection object',
#        'NOTE: Observation time set to mid-point between start time and stop time',
#        'NOTE: Index Record:',
#        '"MROHR_0001","RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.JP2  ","MRO","HIRISE","ESP_041909_1800","ESP_041909_1800_RED  ","1  ","MARS                            ", 41909,"Extended Science Phase        ","Center of Mars                                                             ","2015-07-06T01:30:45     ","1120613486:20832","2015-07-06T01:30:45     ","1120613486:30958","2015-07-06T01:30:51     ","1120613491:64565", 35904, 15160,22.26360,35.7660, 57.6312, 269.506,3663.96, 289.783,  270.0000,  186.2842,    3.6660,  324.3930,    0.2037,    1.6991,   1.57867,     8.639,   14.3734,"YES",   -0.1547,    0.1482,   -0.0630,    0.0646, 0.50,118549.398,"EQUIRECTANGULAR    ",  0.0,   0.000,     17567.5,      7496.5,   -0.1432,    0.0646,   -0.1547,   -0.0300,    0.1367,   -0.0630,    0.1482,    0.0312',
#        'NOTE: HIRISE location data updated from index table entry']},
#      'pdsid': 'ESP_041909_1800_RED',
#      'PDSVolume_Id': 'MROHR_0001',
#      'Phase_angle': '57.559947',
#      'Pole_state': 'none',
#      'Producer_id': 'UA',
#      'Product_creation_time': '2015-08-13T17:12:54.000',
#      'Product_files': {'Product_file': [{'Description': 'MAP PROJECTION FILE',
#         'FileName': 'DSMAP.CAT',
#         'KBytes': '7',
#         'Type': 'Referenced',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/CATALOG/DSMAP.CAT'},
#        {'Description': 'ANNOTATED MERGED IRB BROWSE',
#         'FileName': 'ESP_041909_1800_MIRB.ABROWSE.JPG',
#         'KBytes': '4242',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MIRB.abrowse.jpg'},
#        {'Description': 'MERGED IRB BROWSE',
#         'FileName': 'ESP_041909_1800_MIRB.BROWSE.JPG',
#         'KBytes': '4754',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MIRB.browse.jpg'},
#        {'Description': 'MERGED IRB JP2',
#         'FileName': 'ESP_041909_1800_MIRB.JP2',
#         'KBytes': '272459',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MIRB.JP2'},
#        {'Description': 'MERGED IRB LABEL',
#         'FileName': 'ESP_041909_1800_MIRB.LBL',
#         'KBytes': '9',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MIRB.LBL'},
#        {'Description': 'MERGED IRB THUMBNAIL',
#         'FileName': 'ESP_041909_1800_MIRB.THUMB.JPG',
#         'KBytes': '286',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MIRB.thumb.jpg'},
#        {'Description': 'ANNOTATED MERGED RGB BROWSE',
#         'FileName': 'ESP_041909_1800_MRGB.ABROWSE.JPG',
#         'KBytes': '4240',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MRGB.abrowse.jpg'},
#        {'Description': 'MERGED RGB BROWSE',
#         'FileName': 'ESP_041909_1800_MRGB.BROWSE.JPG',
#         'KBytes': '4748',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MRGB.browse.jpg'},
#        {'Description': 'MERGED RGB JP2',
#         'FileName': 'ESP_041909_1800_MRGB.JP2',
#         'KBytes': '268965',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MRGB.JP2'},
#        {'Description': 'MERGED RGB LABEL',
#         'FileName': 'ESP_041909_1800_MRGB.LBL',
#         'KBytes': '9',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MRGB.LBL'},
#        {'Description': 'MERGED RGB THUMBNAIL',
#         'FileName': 'ESP_041909_1800_MRGB.THUMB.JPG',
#         'KBytes': '286',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_MRGB.thumb.jpg'},
#        {'Description': 'ANNOTATED BROWSE',
#         'FileName': 'ESP_041909_1800_RED.ABROWSE.JPG',
#         'KBytes': '3953',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.abrowse.jpg'},
#        {'Description': 'BROWSE',
#         'FileName': 'ESP_041909_1800_RED.BROWSE.JPG',
#         'KBytes': '4430',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.browse.jpg'},
#        {'Description': 'PRODUCT DATA FILE',
#         'FileName': 'ESP_041909_1800_RED.JP2',
#         'KBytes': '290510',
#         'Type': 'Product',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.JP2'},
#        {'Description': 'PRODUCT LABEL FILE',
#         'FileName': 'ESP_041909_1800_RED.LBL',
#         'KBytes': '9',
#         'Type': 'Product',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.LBL'},
#        {'Description': 'GREYSCALE BROWSE',
#         'FileName': 'ESP_041909_1800_RED.NOMAP.BROWSE.JPG',
#         'KBytes': '8518',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.NOMAP.browse.jpg'},
#        {'Description': 'GREYSCALE JP2',
#         'FileName': 'ESP_041909_1800_RED.NOMAP.JP2',
#         'KBytes': '141616',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.NOMAP.JP2'},
#        {'Description': 'GREYSCALE THUMBNAIL',
#         'FileName': 'ESP_041909_1800_RED.NOMAP.THUMB.JPG',
#         'KBytes': '598',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.NOMAP.thumb.jpg'},
#        {'Description': 'QUICKLOOK JP2',
#         'FileName': 'ESP_041909_1800_RED.QLOOK.JP2',
#         'KBytes': '136414',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.QLOOK.JP2'},
#        {'Description': 'THUMBNAIL',
#         'FileName': 'ESP_041909_1800_RED.THUMB.JPG',
#         'KBytes': '288',
#         'Type': 'Browse',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.thumb.jpg'},
#        {'Creation_date': '2015-10-22T03:39:36.276',
#         'Description': 'PRODUCT KML FILE <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'ESP_041909_1800_RED_LBL.KML',
#         'KBytes': '3',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/kmlfiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/esp/orb_041900_041999/esp_041909_1800/esp_041909_1800_red_lbl.kml'},
#        {'Creation_date': '2015-10-22T03:39:36.118',
#         'Description': 'PRODUCT FOOTPRINT SHAPEFILES (TAR.GZ) <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'ESP_041909_1800_RED_LBL.TAR.GZ',
#         'KBytes': '4',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/shapefiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/esp/orb_041900_041999/esp_041909_1800/esp_041909_1800_red_lbl.tar.gz'},
#        {'Creation_date': '2015-10-22T03:39:35.981',
#         'Description': 'PRODUCT FOOTPRINT SHAPEFILES (ZIP) <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#         'FileName': 'ESP_041909_1800_RED_LBL.ZIP',
#         'KBytes': '29',
#         'Type': 'Derived',
#         'URL': 'http://ode.rsl.wustl.edu/mars/datafile/shapefiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/esp/orb_041900_041999/esp_041909_1800/esp_041909_1800_red_lbl.zip'},
#        {'Description': 'DESCRIPTION FILE',
#         'FileName': 'JP2INFO.TXT',
#         'KBytes': '9',
#         'Type': 'Referenced',
#         'URL': 'https://hirise.lpl.arizona.edu/PDS/DOCUMENT/JP2INFO.TXT'}]},
#      'Product_version_id': '1.0',
#      'ProductURL': 'http://ode.rsl.wustl.edu/mars/indexproductpage.aspx?product_id=ESP_041909_1800_RED&product_idGeo=24728280',
#      'pt': 'RDRV11',
#      'RelativePathtoVol': 'rdr\\esp\\orb_041900_041999\\esp_041909_1800\\',
#      'Solar_longitude': '8.638808',
#      'Solar_time': '14.37386',
#      'SpaceCraft_clock_start_count': '1120613486:30958',
#      'SpaceCraft_clock_stop_count': '1120613491:64565',
#      'Start_orbit_number': '41909',
#      'Stop_orbit_number': '41909',
#      'Target_name': 'MARS',
#      'UTC_start_time': '2015-07-06T01:30:45.489',
#      'UTC_stop_time': '2015-07-06T01:30:51.002',
#      'Westernmost_longitude': '359.937'}]},
#   'QuerySummary': {'Date': '2020-09-14T08:26:21.003',
#    'easternlon': '0.5',
#    'ihid': 'mro',
#    'iid': 'hirise',
#    'loc': 'f',
#    'maxlat': '0.5',
#    'minlat': '-0.5',
#    'output': 'JSON',
#    'pt': 'rdrv11',
#    'query': 'PRODUCT',
#    'Query_Elapsed_Time': '00:00:00.2500061',
#    'results': 'FMPC',
#    'target': 'mars',
#    'westernlon': '359.5'},
#   'Status': 'Success'}}

# %% [markdown]
# ### Read out product results

# %%
list(req.json()['ODEResults'].keys())
# Out:
# ['Count', 'Products', 'QuerySummary', 'Status']

# %%
list(req.json()['ODEResults']['Products'].keys())
# Out:
# ['Product']

# %%
type(req.json()['ODEResults']['Products']['Product'])
# Out:
# list

# %%
len(req.json()['ODEResults']['Products']['Product'])
# Out:
# 6

# %%
req.json()['ODEResults']['Products']['Product'][0]
# Out:
# {'BB_georeferenced': 'True',
#  'Center_georeferenced': 'True',
#  'Center_latitude': '-0.012',
#  'Center_longitude': '0.007',
#  'Comment': 'Center of Mars',
#  'Data_Set_Id': 'MRO-M-HIRISE-3-RDR-V1.1',
#  'Description': 'HiRISE projected and mosaicked product  HiRISE RDR V1.1 files has map projection data embedded in the header - please see SIS for more details.',
#  'Easternmost_longitude': '0.044',
#  'Emission_angle': '0.172008',
#  'External_url': 'http://www.uahirise.org/PSP_007361_1800',
#  'External_url2': 'jpip://hijpip.lpl.arizona.edu:8064/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.JP2',
#  'FilesURL': 'http://ode.rsl.wustl.edu/mars/productfiles.aspx?product_id=PSP_007361_1800_COLOR&product_idGeo=14284086',
#  'Footprint_C0_geometry': 'POLYGON ((0.044 -0.237, 0.025 -0.239, -0.03 0.212, -0.011 0.214, 0.044 -0.237))',
#  'Footprint_geometry': 'GEOMETRYCOLLECTION (POLYGON ((360 -0.034, 359.97 0.212, 359.989 0.214, 360 0.124, 360 -0.034)), POLYGON ((0.044 -0.237, 0.025 -0.239, 0 -0.034, 0 0.124, 0.044 -0.237)))',
#  'Footprint_GL_geometry': 'POLYGON ((0.044 -0.237, 0.025 -0.239, 359.97 0.212, 359.989 0.214, 0.044 -0.237))',
#  'Footprint_NP_geometry': 'MULTIPOLYGON EMPTY',
#  'Footprint_souce': 'PDS Archive Index Table',
#  'Footprint_SP_geometry': 'MULTIPOLYGON EMPTY',
#  'Footprints_cross_meridian': 'True',
#  'ihid': 'MRO',
#  'iid': 'HIRISE',
#  'Incidence_angle': '44.12436',
#  'LabelFileName': 'psp_007361_1800_color.lbl',
#  'LabelURL': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.LBL',
#  'Map_resolution': '118549.39504661',
#  'Map_scale': '0.5',
#  'Maximum_latitude': '0.214',
#  'Minimum_latitude': '-0.239',
#  'Observation_id': 'PSP_007361_1800',
#  'Observation_time': '2008-02-21T00:58:55.113',
#  'ODE_notes': {'ODE_note': ['NOTE: Product Type set by ODE',
#    'NOTE: Label keyword Orbit number value used for start orbit number value',
#    'NOTE: Label keyword Orbit number value used for stop orbit number value',
#    'NOTE: Map Resolution set from label map projection object',
#    'NOTE: Map scale from the label map projection object',
#    'NOTE: Observation time set to mid-point between start time and stop time',
#    'NOTE: Index Record:',
#    '"MROHR_0001","RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.JP2","MRO","HIRISE","PSP_007361_1800","PSP_007361_1800_COLOR","2  ","MARS                            ",  7361,"Primary Science Phase         ","Center of Mars                                                             ","2008-02-21T00:58:50     ","888022750:31012 ","2008-02-21T00:58:50     ","888022750:35907 ","2008-02-21T00:58:59     ","888022759:12115 ", 53697,  8672, 0.16470,44.1243, 43.9695, 269.136,3663.26, 269.138,  270.0000,  200.4429,   14.0629,  317.7460,   -0.0145,  359.9950,   1.63332,    34.809,   14.8174,"YES",   -0.2453,    0.2165,   -0.0650,    0.0797, 0.50,118549.398,"EQUIRECTANGULAR    ",  0.0,   0.000,     25125.5,      3486.5,   -0.2370,    0.0435,   -0.2392,    0.0252,    0.2115,   -0.0300,    0.2137,   -0.0110',
#    'NOTE: HIRISE location data updated from index table entry']},
#  'pdsid': 'PSP_007361_1800_COLOR',
#  'PDSVolume_Id': 'MROHR_0001',
#  'Phase_angle': '43.954011',
#  'Pole_state': 'none',
#  'Producer_id': 'UA',
#  'Product_creation_time': '2010-04-07T02:05:16.000',
#  'Product_files': {'Product_file': [{'Description': 'MAP PROJECTION FILE',
#     'FileName': 'DSMAP.CAT',
#     'KBytes': '7',
#     'Type': 'Referenced',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/CATALOG/DSMAP.CAT'},
#    {'Description': 'DESCRIPTION FILE',
#     'FileName': 'JP2INFO.TXT',
#     'KBytes': '9',
#     'Type': 'Referenced',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/DOCUMENT/JP2INFO.TXT'},
#    {'Description': 'ANNOTATED BROWSE',
#     'FileName': 'PSP_007361_1800_COLOR.ABROWSE.JPG',
#     'KBytes': '1036',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.abrowse.jpg'},
#    {'Description': 'BROWSE',
#     'FileName': 'PSP_007361_1800_COLOR.BROWSE.JPG',
#     'KBytes': '1191',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.browse.jpg'},
#    {'Description': 'PRODUCT DATA FILE',
#     'FileName': 'PSP_007361_1800_COLOR.JP2',
#     'KBytes': '189587',
#     'Type': 'Product',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.JP2'},
#    {'Description': 'PRODUCT LABEL FILE',
#     'FileName': 'PSP_007361_1800_COLOR.LBL',
#     'KBytes': '8',
#     'Type': 'Product',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.LBL'},
#    {'Description': 'QUICKLOOK JP2',
#     'FileName': 'PSP_007361_1800_COLOR.QLOOK.JP2',
#     'KBytes': '94329',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.QLOOK.JP2'},
#    {'Description': 'THUMBNAIL',
#     'FileName': 'PSP_007361_1800_COLOR.THUMB.JPG',
#     'KBytes': '342',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.thumb.jpg'},
#    {'Creation_date': '2015-10-17T03:49:09.983',
#     'Description': 'PRODUCT KML FILE <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#     'FileName': 'PSP_007361_1800_COLOR_LBL.KML',
#     'KBytes': '3',
#     'Type': 'Derived',
#     'URL': 'http://ode.rsl.wustl.edu/mars/datafile/kmlfiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/psp/orb_007300_007399/psp_007361_1800/psp_007361_1800_color_lbl.kml'},
#    {'Creation_date': '2015-10-17T03:49:09.820',
#     'Description': 'PRODUCT FOOTPRINT SHAPEFILES (TAR.GZ) <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#     'FileName': 'PSP_007361_1800_COLOR_LBL.TAR.GZ',
#     'KBytes': '4',
#     'Type': 'Derived',
#     'URL': 'http://ode.rsl.wustl.edu/mars/datafile/shapefiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/psp/orb_007300_007399/psp_007361_1800/psp_007361_1800_color_lbl.tar.gz'},
#    {'Creation_date': '2015-10-17T03:49:09.711',
#     'Description': 'PRODUCT FOOTPRINT SHAPEFILES (ZIP) <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#     'FileName': 'PSP_007361_1800_COLOR_LBL.ZIP',
#     'KBytes': '29',
#     'Type': 'Derived',
#     'URL': 'http://ode.rsl.wustl.edu/mars/datafile/shapefiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/psp/orb_007300_007399/psp_007361_1800/psp_007361_1800_color_lbl.zip'},
#    {'Description': 'IRB BROWSE',
#     'FileName': 'PSP_007361_1800_IRB.NOMAP.BROWSE.JPG',
#     'KBytes': '3925',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_IRB.NOMAP.browse.jpg'},
#    {'Description': 'IRB JP2',
#     'FileName': 'PSP_007361_1800_IRB.NOMAP.JP2',
#     'KBytes': '196935',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_IRB.NOMAP.JP2'},
#    {'Description': 'IRB THUMBNAIL',
#     'FileName': 'PSP_007361_1800_IRB.NOMAP.THUMB.JPG',
#     'KBytes': '277',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_IRB.NOMAP.thumb.jpg'},
#    {'Description': 'ANNOTATED MERGED IRB BROWSE',
#     'FileName': 'PSP_007361_1800_MIRB.ABROWSE.JPG',
#     'KBytes': '4739',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.abrowse.jpg'},
#    {'Description': 'MERGED IRB BROWSE',
#     'FileName': 'PSP_007361_1800_MIRB.BROWSE.JPG',
#     'KBytes': '5315',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.browse.jpg'},
#    {'Description': 'MERGED IRB JP2',
#     'FileName': 'PSP_007361_1800_MIRB.JP2',
#     'KBytes': '424919',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.JP2'},
#    {'Description': 'MERGED IRB LABEL',
#     'FileName': 'PSP_007361_1800_MIRB.LBL',
#     'KBytes': '9',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.LBL'},
#    {'Description': 'MERGED IRB THUMBNAIL',
#     'FileName': 'PSP_007361_1800_MIRB.THUMB.JPG',
#     'KBytes': '324',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.thumb.jpg'},
#    {'Description': 'ANNOTATED MERGED RGB BROWSE',
#     'FileName': 'PSP_007361_1800_MRGB.ABROWSE.JPG',
#     'KBytes': '4738',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.abrowse.jpg'},
#    {'Description': 'MERGED RGB BROWSE',
#     'FileName': 'PSP_007361_1800_MRGB.BROWSE.JPG',
#     'KBytes': '5322',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.browse.jpg'},
#    {'Description': 'MERGED RGB JP2',
#     'FileName': 'PSP_007361_1800_MRGB.JP2',
#     'KBytes': '412242',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.JP2'},
#    {'Description': 'MERGED RGB LABEL',
#     'FileName': 'PSP_007361_1800_MRGB.LBL',
#     'KBytes': '9',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.LBL'},
#    {'Description': 'MERGED RGB THUMBNAIL',
#     'FileName': 'PSP_007361_1800_MRGB.THUMB.JPG',
#     'KBytes': '324',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.thumb.jpg'},
#    {'Description': 'RGB BROWSE',
#     'FileName': 'PSP_007361_1800_RGB.NOMAP.BROWSE.JPG',
#     'KBytes': '3404',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RGB.NOMAP.browse.jpg'},
#    {'Description': 'RGB JP2',
#     'FileName': 'PSP_007361_1800_RGB.NOMAP.JP2',
#     'KBytes': '193934',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RGB.NOMAP.JP2'},
#    {'Description': 'RGB THUMBNAIL',
#     'FileName': 'PSP_007361_1800_RGB.NOMAP.THUMB.JPG',
#     'KBytes': '245',
#     'Type': 'Browse',
#     'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RGB.NOMAP.thumb.jpg'}]},
#  'Product_version_id': '2.0',
#  'ProductURL': 'http://ode.rsl.wustl.edu/mars/indexproductpage.aspx?product_id=PSP_007361_1800_COLOR&product_idGeo=14284086',
#  'pt': 'RDRV11',
#  'RelativePathtoVol': 'rdr\\psp\\orb_007300_007399\\psp_007361_1800\\',
#  'Solar_longitude': '34.80857',
#  'Solar_time': '14.81746',
#  'SpaceCraft_clock_start_count': '888022750:35907',
#  'SpaceCraft_clock_stop_count': '888022759:12115',
#  'Start_orbit_number': '7361',
#  'Stop_orbit_number': '7361',
#  'Target_name': 'MARS',
#  'UTC_start_time': '2008-02-21T00:58:50.769',
#  'UTC_stop_time': '2008-02-21T00:58:59.457',
#  'Westernmost_longitude': '359.97'}

# %%
help(ode)
# Out:
# Help on module ode:
#
# NAME
#     ode
#
# FUNCTIONS
#     find_product_file(product_files, product_type, descriptors={'ctx': {'product_image': ('Description', 'PRODUCT DATA FILE WITH LABEL'), 'browse_image': ('Description', 'BROWSE IMAGE'), 'browse_thumbnail': ('Description', 'THUMBNAIL IMAGE')}, 'hirise': {'product_image': ('Description', 'PRODUCT DATA FILE'), 'product_label': ('Description', 'PRODUCT LABEL FILE'), 'browse_image': ('Description', 'BROWSE'), 'browse_thumbnail': ('Description', 'THUMBNAIL')}})
#
#     readout_product_files(product_json)
#
#     readout_product_footprint(request)
#
#     readout_product_meta(product_json)
#
#     request_product(PRODUCTID, api_endpoint)
#
#     request_products(api_endpoint, bbox, target=None, host=None, instr=None, ptype=None)
#         bbox = {
#             'minlat': [-65:65],
#             'minlat': [-65:65],
#             'westlon': [0:360],
#             'eastlon': [0:360]
#         }
#         'ptype' (eg, "rdrv11") is used only when 'instr' is also defined (e.g, "hirise").
#
#     requested_product_files(request)
#
#     requested_products(request)
#
# DATA
#     API_URL = 'https://oderest.rsl.wustl.edu/live2'
#     DATASETS = {'ctx': {'host': 'mro', 'instr': 'ctx', 'ptype': 'edr'}, 'h...
#     DESCRIPTORS = {'ctx': {'browse_image': ('Description', 'BROWSE IMAGE')...
#
# FILE
#     /Users/chbrandt/Coisas/repos/NEANIAS/notebooks/ode.py

# %%
reload(ode)
products = ode.requested_products(req)

# %%
len(products)
# Out:
# 6

# %%
i = 0
pi = products[i]

imeta = ode.readout_product_meta(pi)
ifiles = ode.readout_product_files(pi)
ifprint = ode.readout_product_footprint(pi)

# %%
imeta
# Out:
# {'id': 'PSP_007361_1800_COLOR',
#  'mission': 'MRO',
#  'inst': 'HIRISE',
#  'type': 'RDRV11'}

# %%
ifiles
# Out:
# [{'Description': 'MAP PROJECTION FILE',
#   'FileName': 'DSMAP.CAT',
#   'KBytes': '7',
#   'Type': 'Referenced',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/CATALOG/DSMAP.CAT'},
#  {'Description': 'DESCRIPTION FILE',
#   'FileName': 'JP2INFO.TXT',
#   'KBytes': '9',
#   'Type': 'Referenced',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/DOCUMENT/JP2INFO.TXT'},
#  {'Description': 'ANNOTATED BROWSE',
#   'FileName': 'PSP_007361_1800_COLOR.ABROWSE.JPG',
#   'KBytes': '1036',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.abrowse.jpg'},
#  {'Description': 'BROWSE',
#   'FileName': 'PSP_007361_1800_COLOR.BROWSE.JPG',
#   'KBytes': '1191',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.browse.jpg'},
#  {'Description': 'PRODUCT DATA FILE',
#   'FileName': 'PSP_007361_1800_COLOR.JP2',
#   'KBytes': '189587',
#   'Type': 'Product',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.JP2'},
#  {'Description': 'PRODUCT LABEL FILE',
#   'FileName': 'PSP_007361_1800_COLOR.LBL',
#   'KBytes': '8',
#   'Type': 'Product',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.LBL'},
#  {'Description': 'QUICKLOOK JP2',
#   'FileName': 'PSP_007361_1800_COLOR.QLOOK.JP2',
#   'KBytes': '94329',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.QLOOK.JP2'},
#  {'Description': 'THUMBNAIL',
#   'FileName': 'PSP_007361_1800_COLOR.THUMB.JPG',
#   'KBytes': '342',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.thumb.jpg'},
#  {'Creation_date': '2015-10-17T03:49:09.983',
#   'Description': 'PRODUCT KML FILE <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#   'FileName': 'PSP_007361_1800_COLOR_LBL.KML',
#   'KBytes': '3',
#   'Type': 'Derived',
#   'URL': 'http://ode.rsl.wustl.edu/mars/datafile/kmlfiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/psp/orb_007300_007399/psp_007361_1800/psp_007361_1800_color_lbl.kml'},
#  {'Creation_date': '2015-10-17T03:49:09.820',
#   'Description': 'PRODUCT FOOTPRINT SHAPEFILES (TAR.GZ) <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#   'FileName': 'PSP_007361_1800_COLOR_LBL.TAR.GZ',
#   'KBytes': '4',
#   'Type': 'Derived',
#   'URL': 'http://ode.rsl.wustl.edu/mars/datafile/shapefiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/psp/orb_007300_007399/psp_007361_1800/psp_007361_1800_color_lbl.tar.gz'},
#  {'Creation_date': '2015-10-17T03:49:09.711',
#   'Description': 'PRODUCT FOOTPRINT SHAPEFILES (ZIP) <A HREF="PAGEHELP/QUICKSTARTGUIDE/ABOUTFOOTPRINTS.HTM" TARGET="_BLANK">HELP</A>',
#   'FileName': 'PSP_007361_1800_COLOR_LBL.ZIP',
#   'KBytes': '29',
#   'Type': 'Derived',
#   'URL': 'http://ode.rsl.wustl.edu/mars/datafile/shapefiles/mro-m-hirise-3-rdr-v11/mrohr_0001/rdr/psp/orb_007300_007399/psp_007361_1800/psp_007361_1800_color_lbl.zip'},
#  {'Description': 'IRB BROWSE',
#   'FileName': 'PSP_007361_1800_IRB.NOMAP.BROWSE.JPG',
#   'KBytes': '3925',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_IRB.NOMAP.browse.jpg'},
#  {'Description': 'IRB JP2',
#   'FileName': 'PSP_007361_1800_IRB.NOMAP.JP2',
#   'KBytes': '196935',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_IRB.NOMAP.JP2'},
#  {'Description': 'IRB THUMBNAIL',
#   'FileName': 'PSP_007361_1800_IRB.NOMAP.THUMB.JPG',
#   'KBytes': '277',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_IRB.NOMAP.thumb.jpg'},
#  {'Description': 'ANNOTATED MERGED IRB BROWSE',
#   'FileName': 'PSP_007361_1800_MIRB.ABROWSE.JPG',
#   'KBytes': '4739',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.abrowse.jpg'},
#  {'Description': 'MERGED IRB BROWSE',
#   'FileName': 'PSP_007361_1800_MIRB.BROWSE.JPG',
#   'KBytes': '5315',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.browse.jpg'},
#  {'Description': 'MERGED IRB JP2',
#   'FileName': 'PSP_007361_1800_MIRB.JP2',
#   'KBytes': '424919',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.JP2'},
#  {'Description': 'MERGED IRB LABEL',
#   'FileName': 'PSP_007361_1800_MIRB.LBL',
#   'KBytes': '9',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.LBL'},
#  {'Description': 'MERGED IRB THUMBNAIL',
#   'FileName': 'PSP_007361_1800_MIRB.THUMB.JPG',
#   'KBytes': '324',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MIRB.thumb.jpg'},
#  {'Description': 'ANNOTATED MERGED RGB BROWSE',
#   'FileName': 'PSP_007361_1800_MRGB.ABROWSE.JPG',
#   'KBytes': '4738',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.abrowse.jpg'},
#  {'Description': 'MERGED RGB BROWSE',
#   'FileName': 'PSP_007361_1800_MRGB.BROWSE.JPG',
#   'KBytes': '5322',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.browse.jpg'},
#  {'Description': 'MERGED RGB JP2',
#   'FileName': 'PSP_007361_1800_MRGB.JP2',
#   'KBytes': '412242',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.JP2'},
#  {'Description': 'MERGED RGB LABEL',
#   'FileName': 'PSP_007361_1800_MRGB.LBL',
#   'KBytes': '9',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.LBL'},
#  {'Description': 'MERGED RGB THUMBNAIL',
#   'FileName': 'PSP_007361_1800_MRGB.THUMB.JPG',
#   'KBytes': '324',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_MRGB.thumb.jpg'},
#  {'Description': 'RGB BROWSE',
#   'FileName': 'PSP_007361_1800_RGB.NOMAP.BROWSE.JPG',
#   'KBytes': '3404',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RGB.NOMAP.browse.jpg'},
#  {'Description': 'RGB JP2',
#   'FileName': 'PSP_007361_1800_RGB.NOMAP.JP2',
#   'KBytes': '193934',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RGB.NOMAP.JP2'},
#  {'Description': 'RGB THUMBNAIL',
#   'FileName': 'PSP_007361_1800_RGB.NOMAP.THUMB.JPG',
#   'KBytes': '245',
#   'Type': 'Browse',
#   'URL': 'https://hirise.lpl.arizona.edu/PDS/EXTRAS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RGB.NOMAP.thumb.jpg'}]

# %%
ifprint
# Out:
# 'POLYGON ((0.044 -0.237, 0.025 -0.239, 359.97 0.212, 359.989 0.214, 0.044 -0.237))'

# %%
ode.find_product_file(product_files=ifiles, product_type='product_image', descriptors=ode.DESCRIPTORS['hirise'])
# Out:
# {'Description': 'PRODUCT DATA FILE',
#  'FileName': 'PSP_007361_1800_COLOR.JP2',
#  'KBytes': '189587',
#  'Type': 'Product',
#  'URL': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.JP2'}

# %% [markdown]
# ## Condensed workflow

# %%
reload(ode)

INSTRUMENT = 'hirise'

req = ode.request_products(ode.API_URL, bbox=bbox, target='mars', host='mro', instr=INSTRUMENT, ptype='rdrv11')

products = ode.requested_products(req)

products_output = []
for i,product in enumerate(products):
    _meta = ode.readout_product_meta(product)
    _files = ode.readout_product_files(product)
    _fprint = ode.readout_product_footprint(product)
    _pfile = ode.find_product_file(product_files=_files, product_type='product_image', descriptors=ode.DESCRIPTORS[INSTRUMENT])
    _pfile = _pfile['URL']
    _lfile = ode.find_product_file(product_files=_files, product_type='product_label', descriptors=ode.DESCRIPTORS[INSTRUMENT])
    _lfile = _lfile['URL']
    _dout = _meta
    _dout['geometry'] = _fprint
    _dout['image_url'] = _pfile
    _dout['label_url'] = _lfile
    products_output.append(_dout)

print(products_output)
# Out:
# [{'id': 'PSP_007361_1800_COLOR', 'mission': 'MRO', 'inst': 'HIRISE', 'type': 'RDRV11', 'geometry': 'POLYGON ((0.044 -0.237, 0.025 -0.239, 359.97 0.212, 359.989 0.214, 0.044 -0.237))', 'image_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.JP2', 'label_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.LBL'}, {'id': 'PSP_007361_1800_RED', 'mission': 'MRO', 'inst': 'HIRISE', 'type': 'RDRV11', 'geometry': 'POLYGON ((0.08 -0.234, 359.989 -0.245, 359.935 0.206, 0.025 0.216, 0.08 -0.234))', 'image_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.JP2', 'label_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.LBL'}, {'id': 'ESP_023817_1800_COLOR', 'mission': 'MRO', 'inst': 'HIRISE', 'type': 'RDRV11', 'geometry': 'POLYGON ((359.942 0, 359.923 -0.002, 359.899 0.202, 359.918 0.204, 359.942 0))', 'image_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_COLOR.JP2', 'label_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_COLOR.LBL'}, {'id': 'ESP_023817_1800_RED', 'mission': 'MRO', 'inst': 'HIRISE', 'type': 'RDRV11', 'geometry': 'POLYGON ((359.978 0.004, 359.887 -0.007, 359.863 0.197, 359.954 0.208, 359.978 0.004))', 'image_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.JP2', 'label_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.LBL'}, {'id': 'ESP_041909_1800_COLOR', 'mission': 'MRO', 'inst': 'HIRISE', 'type': 'RDRV11', 'geometry': 'POLYGON ((0.023 -0.146, 0.001 -0.149, 359.968 0.142, 359.989 0.145, 0.023 -0.146))', 'image_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_COLOR.JP2', 'label_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_COLOR.LBL'}, {'id': 'ESP_041909_1800_RED', 'mission': 'MRO', 'inst': 'HIRISE', 'type': 'RDRV11', 'geometry': 'POLYGON ((0.065 -0.143, 359.97 -0.155, 359.937 0.137, 0.031 0.148, 0.065 -0.143))', 'image_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.JP2', 'label_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.LBL'}]

# %%
import geopandas as gpd
import shapely

for prod in products_output:
    prod['geometry'] = shapely.wkt.loads(prod['geometry'])

gdf = gpd.GeoDataFrame(products_output)

gdf.to_file('bla.geojson', driver='GeoJSON')

# %%
# !cat 'bla.geojson'
# Out:
# {
# "type": "FeatureCollection",
# "features": [
# { "type": "Feature", "properties": { "id": "PSP_007361_1800_COLOR", "mission": "MRO", "inst": "HIRISE", "type": "RDRV11", "image_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/PSP\/ORB_007300_007399\/PSP_007361_1800\/PSP_007361_1800_COLOR.JP2", "label_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/PSP\/ORB_007300_007399\/PSP_007361_1800\/PSP_007361_1800_COLOR.LBL" }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 0.044, -0.237 ], [ 0.025, -0.239 ], [ 359.97, 0.212 ], [ 359.989, 0.214 ], [ 0.044, -0.237 ] ] ] } },
# { "type": "Feature", "properties": { "id": "PSP_007361_1800_RED", "mission": "MRO", "inst": "HIRISE", "type": "RDRV11", "image_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/PSP\/ORB_007300_007399\/PSP_007361_1800\/PSP_007361_1800_RED.JP2", "label_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/PSP\/ORB_007300_007399\/PSP_007361_1800\/PSP_007361_1800_RED.LBL" }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 0.08, -0.234 ], [ 359.989, -0.245 ], [ 359.935, 0.206 ], [ 0.025, 0.216 ], [ 0.08, -0.234 ] ] ] } },
# { "type": "Feature", "properties": { "id": "ESP_023817_1800_COLOR", "mission": "MRO", "inst": "HIRISE", "type": "RDRV11", "image_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_023800_023899\/ESP_023817_1800\/ESP_023817_1800_COLOR.JP2", "label_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_023800_023899\/ESP_023817_1800\/ESP_023817_1800_COLOR.LBL" }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 359.942, 0.0 ], [ 359.923, -0.002 ], [ 359.899, 0.202 ], [ 359.918, 0.204 ], [ 359.942, 0.0 ] ] ] } },
# { "type": "Feature", "properties": { "id": "ESP_023817_1800_RED", "mission": "MRO", "inst": "HIRISE", "type": "RDRV11", "image_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_023800_023899\/ESP_023817_1800\/ESP_023817_1800_RED.JP2", "label_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_023800_023899\/ESP_023817_1800\/ESP_023817_1800_RED.LBL" }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 359.978, 0.004 ], [ 359.887, -0.007 ], [ 359.863, 0.197 ], [ 359.954, 0.208 ], [ 359.978, 0.004 ] ] ] } },
# { "type": "Feature", "properties": { "id": "ESP_041909_1800_COLOR", "mission": "MRO", "inst": "HIRISE", "type": "RDRV11", "image_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_041900_041999\/ESP_041909_1800\/ESP_041909_1800_COLOR.JP2", "label_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_041900_041999\/ESP_041909_1800\/ESP_041909_1800_COLOR.LBL" }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 0.023, -0.146 ], [ 0.001, -0.149 ], [ 359.968, 0.142 ], [ 359.989, 0.145 ], [ 0.023, -0.146 ] ] ] } },
# { "type": "Feature", "properties": { "id": "ESP_041909_1800_RED", "mission": "MRO", "inst": "HIRISE", "type": "RDRV11", "image_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_041900_041999\/ESP_041909_1800\/ESP_041909_1800_RED.JP2", "label_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_041900_041999\/ESP_041909_1800\/ESP_041909_1800_RED.LBL" }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 0.065, -0.143 ], [ 359.97, -0.155 ], [ 359.937, 0.137 ], [ 0.031, 0.148 ], [ 0.065, -0.143 ] ] ] } }
# ]
# }

# %% [markdown]
# ## Make it a function
#
# Query footprints intersecting given bounding-box; Footprints for a particular instrument.

# %%
import ode

def search_footprints(bbox, dataset):
    """
    Dataset be like: 'mro/hirise/rdrv11'
    """
    host,instr,ptype = dataset.split('/')
    
    req = ode.request_products(ode.API_URL, bbox=bbox, target='mars', host=host, instr=instr, ptype=ptype)
    
    products = ode.requested_products(req)
    
    products_output = []
    for i,product in enumerate(products):
        _meta = ode.readout_product_meta(product)
        _files = ode.readout_product_files(product)
        _fprint = ode.readout_product_footprint(product)
        _pfile = ode.find_product_file(product_files=_files, product_type='product_image', descriptors=ode.DESCRIPTORS[INSTRUMENT])
        _pfile = _pfile['URL']
        _lfile = ode.find_product_file(product_files=_files, product_type='product_label', descriptors=ode.DESCRIPTORS[INSTRUMENT])
        _lfile = _lfile['URL']
        _dout = _meta
        _dout['geometry'] = _fprint
        _dout['image_url'] = _pfile
        _dout['label_url'] = _lfile
        products_output.append(_dout)

    return products_output


def products_to_geojson(products_output, filename):
    import geopandas as gpd
    import shapely

    for prod in products_output:
        try:
            prod['geometry'] = shapely.wkt.loads(prod['geometry'])
        except TypeError as err:
            print("Error in: ", prod)
#             raise err
        
    gdf = gpd.GeoDataFrame(products_output)

    gdf.to_file(filename, driver='GeoJSON')
    print("File '{}' written.".format(filename))

# %%
print(bbox)
# Out:
# {'minlat': -0.5, 'maxlat': 0.5, 'westlon': 359.5, 'eastlon': 0.5}

# %%
# define query
bbox = {'minlat': -0.5, 'maxlat': 0.5, 'westlon': 359.5, 'eastlon': 0.5}
dataset = 'mro/hirise/rdrv11'

_dset = dataset.replace('/','-')
_bbox = ','.join(str(val) for val in bbox.values())

filename = '{dset}_{bbox}.geojson'.format(dset=_dset,bbox=_bbox)

# query products
products = search_footprints(bbox=bbox, dataset=dataset)

# %%
# import json
# print(json.dumps(products, indent=2))
products
# Out:
# [{'id': 'PSP_007361_1800_COLOR',
#   'mission': 'MRO',
#   'inst': 'HIRISE',
#   'type': 'RDRV11',
#   'geometry': 'POLYGON ((0.044 -0.237, 0.025 -0.239, 359.97 0.212, 359.989 0.214, 0.044 -0.237))',
#   'image_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.JP2',
#   'label_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_COLOR.LBL'},
#  {'id': 'PSP_007361_1800_RED',
#   'mission': 'MRO',
#   'inst': 'HIRISE',
#   'type': 'RDRV11',
#   'geometry': 'POLYGON ((0.08 -0.234, 359.989 -0.245, 359.935 0.206, 0.025 0.216, 0.08 -0.234))',
#   'image_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.JP2',
#   'label_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/PSP/ORB_007300_007399/PSP_007361_1800/PSP_007361_1800_RED.LBL'},
#  {'id': 'ESP_023817_1800_COLOR',
#   'mission': 'MRO',
#   'inst': 'HIRISE',
#   'type': 'RDRV11',
#   'geometry': 'POLYGON ((359.942 0, 359.923 -0.002, 359.899 0.202, 359.918 0.204, 359.942 0))',
#   'image_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_COLOR.JP2',
#   'label_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_COLOR.LBL'},
#  {'id': 'ESP_023817_1800_RED',
#   'mission': 'MRO',
#   'inst': 'HIRISE',
#   'type': 'RDRV11',
#   'geometry': 'POLYGON ((359.978 0.004, 359.887 -0.007, 359.863 0.197, 359.954 0.208, 359.978 0.004))',
#   'image_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.JP2',
#   'label_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_023800_023899/ESP_023817_1800/ESP_023817_1800_RED.LBL'},
#  {'id': 'ESP_041909_1800_COLOR',
#   'mission': 'MRO',
#   'inst': 'HIRISE',
#   'type': 'RDRV11',
#   'geometry': 'POLYGON ((0.023 -0.146, 0.001 -0.149, 359.968 0.142, 359.989 0.145, 0.023 -0.146))',
#   'image_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_COLOR.JP2',
#   'label_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_COLOR.LBL'},
#  {'id': 'ESP_041909_1800_RED',
#   'mission': 'MRO',
#   'inst': 'HIRISE',
#   'type': 'RDRV11',
#   'geometry': 'POLYGON ((0.065 -0.143, 359.97 -0.155, 359.937 0.137, 0.031 0.148, 0.065 -0.143))',
#   'image_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.JP2',
#   'label_url': 'https://hirise.lpl.arizona.edu/PDS/RDR/ESP/ORB_041900_041999/ESP_041909_1800/ESP_041909_1800_RED.LBL'}]

# %%
# geojson products
print("Writing {}".format(filename))
products_to_geojson(products, filename)
# Out:
# Writing mro-hirise-rdrv11_-0.5,0.5,359.5,0.5.geojson
# File 'mro-hirise-rdrv11_-0.5,0.5,359.5,0.5.geojson' written.

# %%
# !cat $filename
# Out:
# {
# "type": "FeatureCollection",
# "features": [
# { "type": "Feature", "properties": { "id": "PSP_007361_1800_COLOR", "mission": "MRO", "inst": "HIRISE", "type": "RDRV11", "image_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/PSP\/ORB_007300_007399\/PSP_007361_1800\/PSP_007361_1800_COLOR.JP2", "label_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/PSP\/ORB_007300_007399\/PSP_007361_1800\/PSP_007361_1800_COLOR.LBL" }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 0.044, -0.237 ], [ 0.025, -0.239 ], [ 359.97, 0.212 ], [ 359.989, 0.214 ], [ 0.044, -0.237 ] ] ] } },
# { "type": "Feature", "properties": { "id": "PSP_007361_1800_RED", "mission": "MRO", "inst": "HIRISE", "type": "RDRV11", "image_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/PSP\/ORB_007300_007399\/PSP_007361_1800\/PSP_007361_1800_RED.JP2", "label_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/PSP\/ORB_007300_007399\/PSP_007361_1800\/PSP_007361_1800_RED.LBL" }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 0.08, -0.234 ], [ 359.989, -0.245 ], [ 359.935, 0.206 ], [ 0.025, 0.216 ], [ 0.08, -0.234 ] ] ] } },
# { "type": "Feature", "properties": { "id": "ESP_023817_1800_COLOR", "mission": "MRO", "inst": "HIRISE", "type": "RDRV11", "image_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_023800_023899\/ESP_023817_1800\/ESP_023817_1800_COLOR.JP2", "label_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_023800_023899\/ESP_023817_1800\/ESP_023817_1800_COLOR.LBL" }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 359.942, 0.0 ], [ 359.923, -0.002 ], [ 359.899, 0.202 ], [ 359.918, 0.204 ], [ 359.942, 0.0 ] ] ] } },
# { "type": "Feature", "properties": { "id": "ESP_023817_1800_RED", "mission": "MRO", "inst": "HIRISE", "type": "RDRV11", "image_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_023800_023899\/ESP_023817_1800\/ESP_023817_1800_RED.JP2", "label_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_023800_023899\/ESP_023817_1800\/ESP_023817_1800_RED.LBL" }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 359.978, 0.004 ], [ 359.887, -0.007 ], [ 359.863, 0.197 ], [ 359.954, 0.208 ], [ 359.978, 0.004 ] ] ] } },
# { "type": "Feature", "properties": { "id": "ESP_041909_1800_COLOR", "mission": "MRO", "inst": "HIRISE", "type": "RDRV11", "image_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_041900_041999\/ESP_041909_1800\/ESP_041909_1800_COLOR.JP2", "label_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_041900_041999\/ESP_041909_1800\/ESP_041909_1800_COLOR.LBL" }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 0.023, -0.146 ], [ 0.001, -0.149 ], [ 359.968, 0.142 ], [ 359.989, 0.145 ], [ 0.023, -0.146 ] ] ] } },
# { "type": "Feature", "properties": { "id": "ESP_041909_1800_RED", "mission": "MRO", "inst": "HIRISE", "type": "RDRV11", "image_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_041900_041999\/ESP_041909_1800\/ESP_041909_1800_RED.JP2", "label_url": "https:\/\/hirise.lpl.arizona.edu\/PDS\/RDR\/ESP\/ORB_041900_041999\/ESP_041909_1800\/ESP_041909_1800_RED.LBL" }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 0.065, -0.143 ], [ 359.97, -0.155 ], [ 359.937, 0.137 ], [ 0.031, 0.148 ], [ 0.065, -0.143 ] ] ] } }
# ]
# }

# %%
print(INSTRUMENT)
# Out:
# hirise
